# %%
charset = [
    " ",
    "!",
    "#",
    ")",
    "("
    "\\n",
    ",",
    "⌚",
    "⌛",
    "⏰",
    "⏳",
    "Ⓑ",
    "Ⓘ",
    "Ⓜ",
    "Ⓝ",
    "Ⓟ",
    "ⓑ",
    "ⓘ",
    "ⓜ",
    "ⓝ",
    "ⓟ",
    "⚰",
    "🌇",
    "🌉",
    "🌍",
    "🌝",
    "🌞",
    "🎉",
    "🎩",
    "🏠",
    "🏡",
    "🏥",
    "🏳",
    "👒",
    "👦",
    "👧",
    "👨",
    "👰",
    "👴",
    "👵",
    "👶",
    "👹",
    "💬",
    "💭",
    "📅",
    "📆",
    "📌",
    "📕",
    "📖",
    "🔍",
    "🔎",
    "🔟",
    "🔠",
    "🔡",
    "🔢",
    "🔧",
    "🕑",
    "🕘",
    "🗓",
    "🗨",
    "🗯",
    "🗺",
    "😡",
    "😢",
    "😭",
    "🛣",
    "🛤",
    "🥸",
    "🧐",
    "🪛",
    "🪦"
]

# %%
questions_dict = {
    "Jour-mariage": {"begin": "📖🌞", "end": "📕🌝"},
    "Mois-mariage": {"begin": "📖📅", "end": "📕📆"},
    "Annee-mariage": {"begin": "📖🗓", "end": "📕🎉"},
    "Heure-mariage": {"begin": "📖⏰", "end": "📕⌚"},
    "Minute-mariage": {"begin": "📖🕑", "end": "📕🕘"},
    "Prenom-adjoint-maire": {"begin": "📖💬", "end": "📕🗯"},
    "Nom-adjoint-maire": {"begin": "📖🗨", "end": "📕💭"},
    "Ville-mariage": {"begin": "📖🌇", "end": "📕🌉"},
    "Prenom-mari": {"begin": "👨💬", "end": "👦🗯"},
    "Nom-mari": {"begin": "👨🗨", "end": "👦💭"},
    "Profession-mari": {"begin": "👨🔧", "end": "👦🪛"},
    "Ville-naissance-mari": {"begin": "👨🏥🌇", "end": "👦👶🌉"},
    "Departement-naissance-mari": {"begin": "👨🏥🗺", "end": "👦👶📌"},
    "Pays-naissance-mari": {"begin": "👨🏥🏳", "end": "👦👶🌍"},
    "Jour-naissance-mari": {"begin": "👨🏥🌞", "end": "👦👶🌝"},
    "Mois-naissance-mari": {"begin": "👨🏥📅", "end": "👦👶📆"},
    "Annee-naissance-mari": {"begin": "👨🏥🗓", "end": "👦👶🎉"},
    "Age-mari": {"begin": "👨⌛", "end": "👦⏳"},
    "Ville-residence-mari": {"begin": "👨🏠🌇", "end": "👦🏡🌉"},
    "Departement-residence-mari": {"begin": "👨🏠🗺", "end": "👦🏡📌"},
    "Pays-residence-mari": {"begin": "👨🏠🏳", "end": "👦🏡🌍"},
    "Numero-rue-residence-mari": {"begin": "👨🏠🔟", "end": "👦🏡🔢"},
    "Type-rue-residence-mari": {"begin": "👨🏠🛣", "end": "👦🏡🛤"},
    "Nom-rue-residence-mari": {"begin": "👨🏠🔠", "end": "👦🏡🔡"},
    "Prenom-pere-mari": {"begin": "👨👴💬", "end": "👦🎩🗯"},
    "Nom-pere-mari": {"begin": "👨👴🗨", "end": "👦🎩💭"},
    "Profession-pere-mari": {"begin": "👨👴🔧", "end": "👦🎩🪛"},
    "Ville-residence-pere-mari": {"begin": "👨👴🏠🌇", "end": "👦🎩🏡🌉"},
    "Departement-residence-pere-mari": {"begin": "👨👴🏠🗺", "end": "👦🎩🏡📌"},
    "Pays-residence-pere-mari": {"begin": "👨👴🏠🏳", "end": "👦🎩🏡🌍"},
    "Numero-rue-residence-pere-mari": {"begin": "👨👴🏠🔟", "end": "👦🎩🏡🔢"},
    "Type-rue-residence-pere-mari": {"begin": "👨👴🏠🛣", "end": "👦🎩🏡🛤"},
    "Nom-rue-residence-pere-mari": {"begin": "👨👴🏠🔠", "end": "👦🎩🏡🔡"},
    "Prenom-mere-mari": {"begin": "👨👵💬", "end": "👦👒🗯"},
    "Nom-mere-mari": {"begin": "👨👵🗨", "end": "👦👒💭"},
    "Profession-mere-mari": {"begin": "👨👵🔧", "end": "👦👒🪛"},
    "Ville-residence-mere-mari": {"begin": "👨👵🏠🌇", "end": "👦👒🏡🌉"},
    "Departement-residence-mere-mari": {"begin": "👨👵🏠🗺", "end": "👦👒🏡📌"},
    "Pays-residence-mere-mari": {"begin": "👨👵🏠🏳", "end": "👦👒🏡🌍"},
    "Numero-rue-residence-mere-mari": {"begin": "👨👵🏠🔟", "end": "👦👒🏡🔢"},
    "Type-rue-residence-mere-mari": {"begin": "👨👵🏠🛣", "end": "👦👒🏡🛤"},
    "Nom-rue-residence-mere-mari": {"begin": "👨👵🏠🔠", "end": "👦👒🏡🔡"},
    "Prenom-ex-epouse": {"begin": "👨👹💬", "end": "👧😡🗯"},
    "Nom-ex-epouse": {"begin": "👨👹🗨", "end": "👦😡💭"},
    "Prenom-mariee": {"begin": "👰💬", "end": "👦🗯"},
    "Nom-mariee": {"begin": "👰🗨", "end": "👧💭"},
    "Profession-mariee": {"begin": "👰🔧", "end": "👧🪛"},
    "Ville-naissance-mariee": {"begin": "👰🏥🌇", "end": "👧👶🌉"},
    "Departement-naissance-mariee": {"begin": "👰🏥🗺", "end": "👧👶📌"},
    "Pays-naissance-mariee": {"begin": "👰🏥🏳", "end": "👧👶🌍"},
    "Jour-naissance-mariee": {"begin": "👰🏥🌞", "end": "👧👶🌝"},
    "Mois-naissance-mariee": {"begin": "👰🏥📅", "end": "👧👶📆"},
    "Annee-naissance-mariee": {"begin": "👰🏥🗓", "end": "👧👶🎉"},
    "Age-mariee": {"begin": "👰⌛", "end": "👧⏳"},
    "Ville-residence-mariee": {"begin": "👰🏠🌇", "end": "👧🏡🌉"},
    "Departement-residence-mariee": {"begin": "👰🏠🗺", "end": "👧🏡📌"},
    "Pays-residence-mariee": {"begin": "👰🏠🏳", "end": "👧🏡🌍"},
    "Numero-rue-residence-mariee": {"begin": "👰🏠🔟", "end": "👧🏡🔢"},
    "Type-rue-residence-mariee": {"begin": "👰🏠🛣", "end": "👧🏡🛤"},
    "Nom-rue-residence-mariee": {"begin": "👰🏠🔠", "end": "👧🏡🔡"},
    "Prenom-pere-mariee": {"begin": "👰👴💬", "end": "👧🎩🗯"},
    "Nom-pere-mariee": {"begin": "👰👴🗨", "end": "👧🎩💭"},
    "Profession-pere-mariee": {"begin": "👰👴🔧", "end": "👧🎩🪛"},
    "Ville-residence-pere-mariee": {"begin": "👰👴🏠🌇", "end": "👧🎩🏡🌉"},
    "Departement-residence-pere-mariee": {"begin": "👰👴🏠🗺", "end": "👧🎩🏡📌"},
    "Pays-residence-pere-mariee": {"begin": "👰👴🏠🏳", "end": "👧🎩🏡🌍"},
    "Numero-rue-residence-pere-mariee": {"begin": "👰👴🏠🔟", "end": "👧🎩🏡🔢"},
    "Type-rue-residence-pere-mariee": {"begin": "👰👴🏠🛣", "end": "👧🎩🏡🛤"},
    "Nom-rue-residence-pere-mariee": {"begin": "👰👴🏠🔠", "end": "👧🎩🏡🔡"},
    "Prenom-mere-mariee": {"begin": "👰👵💬", "end": "👧👒🗯"},
    "Nom-mere-mariee": {"begin": "👰👵🗨", "end": "👧👒💭"},
    "Profession-mere-mariee": {"begin": "👰👵🔧", "end": "👧👒🪛"},
    "Ville-residence-mere-mariee": {"begin": "👰👵🏠🌇", "end": "👧👒🏡🌉"},
    "Departement-residence-mere-mariee": {"begin": "👰👵🏠🗺", "end": "👧👒🏡📌"},
    "Pays-residence-mere-mariee": {"begin": "👰👵🏠🏳", "end": "👧👒🏡🌍"},
    "Numero-rue-residence-mere-mariee": {"begin": "👰👵🏠🔟", "end": "👧👒🏡🔢"},
    "Type-rue-residence-mere-mariee": {"begin": "👰👵🏠🛣", "end": "👧👒🏡🛤"},
    "Nom-rue-residence-mere-mariee": {"begin": "👰👵🏠🔠", "end": "👧👒🏡🔡"},
    "Prenom-ex-epoux": {"begin": "👰👹💬", "end": "👧😡🗯"},
    "Nom-ex-epoux": {"begin": "👰👹🗨", "end": "👧😡💭"},
    "Prenom-temoin-1": {"begin": "🥸💬", "end": "🧐🗯"},
    "Nom-temoin-1": {"begin": "🥸🗨", "end": "🧐💭"},
    "Profession-temoin-1": {"begin": "🥸🔧", "end": "🧐🪛"},
    "Numero-rue-residence-temoin-1": {"begin": "🥸🏠🔟", "end": "🧐🏡🔢"},
    "Type-rue-residence-temoin-1": {"begin": "🥸🏠🛣", "end": "🧐🏡🛤"},
    "Nom-rue-residence-temoin-1": {"begin": "🥸🏠🔠", "end": "🧐🏡🔡"},
    "Ville-residence-temoin-1": {"begin": "🥸🏠🌇", "end": "🧐🏡🌉"},
    "Departement-residence-temoin-1": {"begin": "🥸🏠🗺", "end": "🧐🏡📌"},
    "Prenom-temoin-2": {"begin": "🥸💬", "end": "🧐🗯"},
    "Nom-temoin-2": {"begin": "🥸🗨", "end": "🧐💭"},
    "Profession-temoin-2": {"begin": "🥸🔧", "end": "🧐🪛"},
    "Numero-rue-residence-temoin-2": {"begin": "🥸🏠🔟", "end": "🧐🏡🔢"},
    "Type-rue-residence-temoin-2": {"begin": "🥸🏠🛣", "end": "🧐🏡🛤"},
    "Nom-rue-residence-temoin-2": {"begin": "🥸🏠🔠", "end": "🧐🏡🔡"},
    "Ville-residence-temoin-2": {"begin": "🥸🏠🌇", "end": "🧐🏡🌉"},
    "Departement-residence-temoin-2": {"begin": "🥸🏠🗺", "end": "🧐🏡📌"},

    'Profession-parents-mariee': {'begin': '👰👴👵🔧', 'end': '👧🎩👒🪛'},
    'Ville-residence-parents-mariee': {'begin': '👰👴👵🏠🌇', 'end': '👧🎩👒🏡🌉'},
    'Departement-residence-parents-mariee': {'begin': '👰👴👵🏠🗺', 'end': '👧🎩👒🏡📌'},
    'Pays-residence-parents-mariee': {'begin': '👰👴👵🏠🏳', 'end': '👧🎩👒🏡🌍'},
    'Numero-rue-residence-parents-mariee': {'begin': '👰👴👵🏠🔟', 'end': '👧🎩👒🏡🔢'},
    'Type-rue-residence-parents-mariee': {'begin': '👰👴👵🏠🛣', 'end': '👧🎩👒🏡🛤'},
    'Nom-rue-residence-parents-mariee': {'begin': '👰👴👵🏠🔠', 'end': '👧🎩👒🏡🔡'},
    'Profession-parents-mariee': {'begin': '👰👴👵🔧', 'end': '👧🎩👒🪛'},

    'Ville-residence-parents-mari': {'begin': '👨👴👵🏠🌇', 'end': '👦🎩👒🏡🌉'},
    'Departement-residence-parents-mari': {'begin': '👨👴👵🏠🗺', 'end': '👦🎩👒🏡📌'},
    'Pays-residence-parents-mari': {'begin': '👨👴👵🏠🏳', 'end': '👦🎩👒🏡🌍'},
    'Numero-rue-residence-parents-mari': {'begin': '👨👴👵🏠🔟', 'end': '👦🎩👒🏡🔢'},
    'Type-rue-residence-parents-mari': {'begin': '👨👴👵🏠🛣', 'end': '👦🎩👒🏡🛤'},
    'Nom-rue-residence-parents-mari': {'begin': '👨👴👵🏠🔠', 'end': '👦🎩👒🏡🔡'},
    'Profession-parents-mari': {'begin': '👨👴👵🔧', 'end': '👦🎩👒🪛'},
}

questions_bool = {
    "Mère-mari-décédée": {"begin": "👨👵💬🪦", "end": "👦👒🗯⚰"},
    "Mère-mariee-décédée": {"begin": "👰👵💬🪦", "end": "👧👒🗯⚰"},
    "Père-mari-décédée": {"begin": "👨👴💬🪦", "end": "👦🎩🗯⚰"},
    "Père-mariee-décédée": {"begin": "👰👴💬🪦", "end": "👧🎩🗯⚰"},
    "Mari-veuf": {"begin": "👨💬😢", "end": "👦🗯😭"},
    "Mariée-veuve": {"begin": "👰💬😢", "end": "👧🗯😭"},
    "Mariée-a-un-ex-époux": {"begin": "👰👹", "end": "👧😡"},
    "Mari-a-une-ex-épouse": {"begin": "👨👹", "end": "👦😡"},
}

# %%
positions = {}
label_length = {}

labels_act = {
    "archives_AD075EC_01M1930_0023-left.png-0": {
        "p1": {
            "Jour-mariage": "vingt-neuf",
            "Mois-mariage": "mars",
            "Annee-mariage": "mil neuf cent trente",
            "Heure-mariage": "onze heures",
            "Minute-mariage": "vingt minutes",
        },
        "p2": {
            "Prenom-mari": "Albert",
            "Nom-mari": "VOLOVITSCH",
            "Profession-mari": "commissionnaire en marchandises",
            "Ville-naissance-mari": "Saint Quentin ",
            "Departement-naissance-mari": "Aisne",
            "Pays-naissance-mari": "",
            "Jour-naissance-mari": "dix",
            "Mois-naissance-mari": "octobre",
            "Annee-naissance-mari": "mil huit cent quatre-vingt-six",
            "Age-mari": "quarante-trois ans",
            "Ville-residence-mari": "Paris",
            "Departement-residence-mari": "",
            "Pays-residence-mari": "",
            "Numero-rue-residence-mari": "40",
            "Type-rue-residence-mari": "rue",
            "Nom-rue-residence-mari": "des Martyrs",
            "Prenom-pere-mari": "Jules",
            "Nom-pere-mari": "VOLOVITSCH",
            # "Pere-mari-decede": "true",
            "Profession-pere-mari": "",
            "Ville-residence-pere-mari": "",
            "Departement-residence-pere-mari": "",
            "Pays-residence-pere-mari": "",
            "Numero-rue-residence-pere-mari": "",
            "Type-rue-residence-pere-mari": "",
            "Nom-rue-residence-pere-mari": "",
            "Prenom-mere-mari": "",
            "Nom-mere-mari": "Fanny LEWINSON",
            # "Mere-mari-decedee": "true",
            "Profession-mere-mari": "",
            "Ville-residence-mere-mari": "",
            "Departement-residence-mere-mari": "",
            "Pays-residence-mere-mari": "",
            "Numero-rue-residence-mere-mari": "",
            "Type-rue-residence-mere-mari": "",
            "Nom-rue-residence-mere-mari": "",
            # "Mari-a-ex-epouse": "false",
            # "Mari-veuf": "false",
            "Prenom-ex-epouse": "",
            "Nom-ex-epouse": ""
        },
        "p3": {
            "Prenom-mariee": "Marguerite C\u00e9lina",
            "Nom-mariee": "MITTE",
            "Profession-mariee": "couturi\u00e8re",
            "Ville-naissance-mariee": "Choisy-le-Roi",
            "Departement-naissance-mariee": "Seine",
            "Pays-naissance-mariee": "",
            "Jour-naissance-mariee": "vingt-dis",
            "Mois-naissance-mariee": "novembre",
            "Annee-naissance-mariee": "mil huit cent quatre-vingt-treize",
            "Age-mariee": "trentesix ans",
            "Ville-residence-mariee": "Paris",
            "Departement-residence-mariee": "",
            "Pays-residence-mariee": "",
            "Numero-rue-residence-mariee": "168",
            "Type-rue-residence-mariee": "rue",
            "Nom-rue-residence-mariee": "Saint Hono\u00e9",
            "Prenom-pere-mariee": "Emile Henri Paul",
            "Nom-pere-mariee": "MITTE",
            # "Pere-mariee-decede": "false",
            "Profession-pere-mariee": "chauffeur",
            "Ville-residence-pere-mariee": "",
            "Departement-residence-pere-mariee": "",
            "Numero-rue-residence-pere-mariee": "",
            "Type-rue-residence-pere-mariee": "",
            "Nom-rue-residence-pere-mariee": "",
            "Prenom-mere-mariee": "Flore",
            "Nom-mere-mariee": "LEBEGUE",
            # "Mere-mariee-decedee": "false",
            "Profession-mere-mariee": "sans profession",
            "Ville-residence-mere-mariee": "Choisy-le-Roi",
            "Departement-residence-mere-mariee": "",
            "Pays-residence-mere-mariee": "",
            "Numero-rue-residence-mere-mariee": "15",
            "Type-rue-residence-mere-mariee": "rue",
            "Nom-rue-residence-mere-mariee": "Passereau",
            # "Mariee-a-ex-epoux": "false",
            # "Mariee-veuve": "false",
            "Prenom-ex-epoux": "",
            "Nom-ex-epoux": "",

        },
        "p4": {
            "Prenom-mari-p4": "Albert",
            "Nom-mari-p4": "VOLOVITSCH",
            "Prenom-mariee-p4": "Marguerite C\u00e9lina",
            "Nom-mariee-p4": "MITTE",
        },
        "p5": {
            "Prenom-temoin-1": "H\u00e9l\u00e8ne",
            "Nom-temoin-1": "SCHEIMANN",
            "Profession-temoin-1": "sans profession",
            "Numero-rue-residence-temoin-1": "7",
            "Type-rue-residence-temoin-1": "rue",
            "Nom-rue-residence-temoin-1": "Montyon",
            "Ville-residence-temoin-1": "",
            "Departement-residence-temoin-1": "",
            "Prenom-temoin-2": "Auguste",
            "Nom-temoin-2": "SEJOURNE",
            "Profession-temoin-2": "peintre en batiment",
            "Numero-rue-residence-temoin-2": "21 ter",
            "Type-rue-residence-temoin-2": "rue",
            "Nom-rue-residence-temoin-2": "Emile Zola",
            "Ville-residence-temoin-2": "Choisy-le-Roi",
            "Departement-residence-temoin-2": "Seine",
            "Prenom-adjoint-maire": "Jean Joseph",
            "Nom-adjoint-maire": "POULALION",
            "Ville-mariage": "Premier arrondissement de Paris",
        }
    }
}

text = {
    "p1": "Le vingt-neuf mars mil neuf cent trente, onze heures vingt minutes ****\ndevant Nous ont comparu publiquement en la maison commune:",
    "p2": "Albert VOLOVITSCH, commissionnaire\nen marchandises, n\u00e9 \u00e0 Saint Quentin (Aisne) le dix octobre mil huit cent quatre-vingt-six,\nquarante-trois ans, domicili\u00e9 \u00e0 Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *\nFanny LEWINSON, son \u00e9pouse, d\u00e9c\u00e9d\u00e9s; d'une part ,/-",
    "p3": "ET Marguerite C\u00e9lina MITTE, couturi\u00e8re,\nn\u00e9e \u00e0 Choisy-le-Roi (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-\nsix ans, domicili\u00e9e \u00e0 Paris, 168, rue Saint Hono\u00e9; fille de Emile Henri Paul MITTE, chauffeur,\net de Flore LEBEGUE, son \u00e9pouse, sans profession, domicili\u00e9es \u00e0 Choisy-le-Roi, 15, rue Passereau\nd'autre part ;- ",
    "p4": "aucune opposition n'existant. Les futurs \u00e9poux d\u00e9clarent qu'il n'a pas \u00e9t\u00e9\nfait de contrat de mariage .- Albert VOLOVITSCH et Marguerite C\u00e9lina MITTE ont d\u00e9clar\u00e9 l'un\napr\u00e8s l'autre vouloir se prendre pour \u00e9poux et Nous avons prononc\u00e9 au nom de la Loi qu'ils\nsont unis par le mariage.",
    "p5": "En pr\u00e9sence de: H\u00e9l\u00e8ne SCHEIMANN, sans profession, 7, rue\nMontyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile\nZola \u00e0 Choisy-le-Roi (Seine) t\u00e9moins majeurs, qui, lecture faite, ont sign\u00e9 avec les \u00e9poux\net Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la\nL\u00e9gion d'Honneur ./."
}

labels_act = {
    "archives_AD075EC_11M549_0094-right.png-0": {
        "p1": {
            "Jour-mariage": "vingt-huit",
            "Mois-mariage": "juin",
            "Annee-mariage": "mil neuf cent trente",
            "Heure-mariage": "douze heures",
            "Minute-mariage": "douze minutes"
        },
        "p2": {
            "Prenom-mari": "Gilbert Alexandre Jean",
            "Nom-mari": "VALO",
            "Profession-mari": "fraiseur",
            "Ville-naissance-mari": "Saint Aubin des Bois",
            "Departement-naissance-mari": "Eure et Loir",
            "Pays-naissance-mari": "",
            "Jour-naissance-mari": "vingt-huit",
            "Mois-naissance-mari": "f\u00e9vrier",
            "Annee-naissance-mari": "mil neuf cent-huit",
            "Age-mari": "vingt-deux ans",
            "Ville-residence-mari": "",
            "Departement-residence-mari": "",
            "Pays-residence-mari": "",
            "Numero-rue-residence-mari": "143",
            "Type-rue-residence-mari": "rue",
            "Nom-rue-residence-mari": "Legendre",
            "Prenom-pere-mari": "Jean Marie Joseph",
            "Nom-pere-mari": "VALO",
            # "Pere-mari-decede": "true",
            "Profession-pere-mari": "",
            "Ville-residence-pere-mari": "",
            "Departement-residence-pere-mari": "",
            "Pays-residence-pere-mari": "",
            "Numero-rue-residence-pere-mari": "",
            "Type-rue-residence-pere-mari": "",
            "Nom-rue-residence-pere-mari": "",
            "Prenom-mere-mari": "Anne Marie",
            "Nom-mere-mari": "LOSSOUARN",
            # "Mere-mari-decedee": "false",
            "Profession-mere-mari": "commer\u00e7ante",
            "Ville-residence-mere-mari": "Saint Aubin (Eure et Loir)",
            "Departement-residence-mere-mari": "",
            "Pays-residence-mere-mari": "",
            "Numero-rue-residence-mere-mari": "",
            "Type-rue-residence-mere-mari": "",
            "Nom-rue-residence-mere-mari": ""
        },
        "p3": {
            "Prenom-mariee": "Marcelle Fernande",
            "Nom-mariee": "WENDER-",
            "Profession-mariee": "couturi\u00e8re",
            "Ville-naissance-mariee": "paris XX \u00b0 arrondissement",
            "Departement-naissance-mariee": "",
            "Pays-naissance-mariee": "",
            "Jour-naissance-mariee": "vingt-neuf",
            "Mois-naissance-mariee": "janvier",
            "Annee-naissance-mariee": "mil neuf cent-dix",
            "Age-mariee": "vingt ans",
            "Ville-residence-mariee": "",
            "Departement-residence-mariee": "",
            "Pays-residence-mariee": "",
            "Numero-rue-residence-mariee": "151 bis",
            "Type-rue-residence-mariee": "rue",
            "Nom-rue-residence-mariee": "de la Roquette",
            "Prenom-pere-mariee": "Fernand Edmond",
            "Nom-pere-mariee": "WENDER",
            # "Pere-mariee-decede": "false",
            "Profession-pere-mariee": "tourneur",
            "Ville-residence-pere-mariee": "",
            "Departement-residence-pere-mariee": "",
            "Numero-rue-residence-pere-mariee": "151 bis",
            "Type-rue-residence-pere-mariee": "rue",
            "Nom-rue-residence-pere-mariee": "de la Roquette",
            "Prenom-mere-mariee": "Marie",
            "Nom-mere-mariee": "BACHELET",
            # "Mere-mariee-decedee": "false",
            "Profession-mere-mariee": "couturi\u00e8re",
            "Ville-residence-mere-mariee": "",
            "Departement-residence-mere-mariee": "",
            "Pays-residence-mere-mariee": "",
            "Numero-rue-residence-mere-mariee": "151 bis",
            "Type-rue-residence-mere-mariee": "rue",
            "Nom-rue-residence-mere-mariee": "de la Roquette",
            # "Mariee-a-ex-epoux": "false",
            # "Mariee-veuve": "false",
            "Prenom-ex-epoux": "",
            "Nom-ex-epoux": ""
        },
        "p4": {
            "Prenom-mari": "Gilbert Alexandre Jean",
            "Nom-mari": "VALO",

            "Prenom-mariee": "Marcelle Fernande",
            "Nom-mariee": "WENDER-"
        },
        "p5": {
            "Prenom-temoin-1": "Jeanne",
            "Nom-temoin-1": "LOUSSOUARN",
            "Profession-temoin-1": "employ\u00e9e \u00e0 la Ville de Paris",
            "Numero-rue-residence-temoin-1": "114",
            "Type-rue-residence-temoin-1": "rue",
            "Nom-rue-residence-temoin-1": "Jean Jaur\u00e8s",
            "Ville-residence-temoin-1": "Levallois Perret",
            "Departement-residence-temoin-1": "",
            "Prenom-temoin-2": "Jean",
            "Nom-temoin-2": "CHEMIN",
            "Profession-temoin-2": "commis principal aux Postes",
            "Numero-rue-residence-temoin-2": "16",
            "Type-rue-residence-temoin-2": "rue",
            "Nom-rue-residence-temoin-2": "de l'Ouest",
            "Ville-residence-temoin-2": "",
            "Departement-residence-temoin-2": "",
            "Prenom-adjoint-maire": "Louis",
            "Nom-adjoint-maire": "PINOTEAU",
            "Ville-mariage": "onzi\u00e8me arrondissement de Paris",
        }
    }
}

# %%
text = {
    "p1" : "le vingt-huit juin mil neuf cent trente, douze heures douze minutes -\ndevant Nous ont comparu publiquement en la maison Commune:",
    "p2" : " Gilbert Alexandre Jean VALO, fraiseur\nn\u00e9 \u00e0 Saint Aubin des Bois, (Eure et Loir), le vingt-huit f\u00e9vrier mil neuf cent-huit, vingt-deux\nans, domicili\u00e9 143 rue Legendre, fils de jean marie Joseph VALO d\u00e9c\u00e9d\u00e9 et de Anne Marie ***\nLOSSOUARN, sa veuve, commer\u00e7ante, domicili\u00e9e \u00e0 Saint Aubin (Eure et Loir), pr\u00e9sente et consen-\ntante, d'une part ./- ",
    "p3" : "Et Marcelle Fernande WENDER- couturi\u00e8re, n\u00e9e \u00e0 paris XX \u00b0 arrondissement, le\nvingt-neuf janvier mil neuf cent-dix, vingt ans, domicili\u00e9e 151 bis rue de la Roquette, avec ses\np\u00e8re et m\u00e8re, fille de Fernand Edmond WENDER, tourneur, et de Marie BACHELET, son \u00e9pouse, coutu-\nri\u00e8re, pr\u00e9sents et consentants, d'autre part. ",
    "p4" : "Aucune opposition n'existant, les futurs \u00e9poux\nles p\u00e8re et m\u00e8re de la future \u00e9pouse d\u00e9clarent qu'il n'a pas \u00e9t\u00e9 fait de contrat de mariage.;\nGilbert Alexandre Jean VALO et Marcelle Fernande WENDER ont d\u00e9clar\u00e9 l'un apr\u00e8s l'autre vouloir\nse prendre pour \u00e9poux et Nous avons prononc\u00e9 Au nom de la loi qu'ils sont unis par le mariage.\n",
    "p5" : "En pr\u00e9sence de: Jeanne LOUSSOUARN, employ\u00e9e \u00e0 la Ville de Paris, 114 rue Jean Jaur\u00e8s \u00e0 Levallois\nPerret et de Jean CHEMIN, commis principal aux Postes, M\u00e9daille Militaire, Croix de Guerre, 16\nrue de l'Ouest, t\u00e9moins majeurs, qui, lecture faite, ont sign\u00e9 avec les \u00e9poux, la m\u00e8re de l'\u00e9poux\nles p\u00e8re et m\u00e8re de l'\u00e9pouse et Nous, Louis PINOTEAU, adjoint au Maire du onzi\u00e8me arrondissement\nde Paris, Chevalier de la L\u00e9gion d'Honneur ./.",
}

# %%
import Levenshtein
import re


def check_for_occurence(occ, text = text):
    #check for occurences of occ in text
    #return a list of tuples (occurence, position) from the first to the last occurence in the text.
    #allow a levenshtein distance of 1/4 of the length of occ and 0 if occ is shorter than 4 characters

    if len(occ) < 4:
        lev = 0
    else:
        lev = len(occ)//3

    #print("check_for_occurence -> occ : ", occ, "lev : ", lev)
    occurences = []
    for i in range(len(text) - len(occ)):

        if Levenshtein.distance(occ, text[i:i+len(occ)]) <= lev:
            match = text[i:i+len(occ)]
            #if a match if found "expand" it until something from charset (dic above) is found

            
            add = 0
            while (i+len(occ)+add < len(text)) and (text[i+len(occ)+add]) not in charset:
                match += text[i+len(occ)+add]
                add += 1
            #print("match : ", match)
                

            #check if there is already an occurence in the list in the len(occ) characters before (overlapping occurences)
            #if there is, replace it with the new one only if it is a better match
            if len(occurences) > 0 and occurences[-1][1] > i - len(occ):
                if Levenshtein.distance(occ, occurences[-1][0]) > Levenshtein.distance(occ, match):
                    #print("Comparison -> ", occurences[-1][0], " : ", Levenshtein.distance(occ, occurences[-1][0]), " vs ", match, " : ", Levenshtein.distance(occ, match))
                    occurences[-1] = (match, i)
            else:
                occurences.append((match, i))
                    
    return occurences

# %%
check_for_occurence("mil huit cent quatre-vingt-treize", text["p3"])
# Out:
# []

# %%
def insert_emojis_around_label(label, paragraph, text=text, act="archives_AD075EC_11M549_0094-right.png-0"):
    # insert emojis around occ in text
    # return the text with emojis around occ
    # if occ is not found, return None

    emojis = questions_dict[label]
    occ = labels_act[act][paragraph][label]
    # print("Occurence :", occ)
    occurences = check_for_occurence(occ, text)
    print("Key :", label, "Ref :", occ, "Occurences :", occurences)
    if len(occurences) == 0:
        return
    else:
        # the position of the occurence in the text is occurences[0][1]

        def search_best_position(occurences, positions=positions, label=label, oc=occ):

            if 'Prenom' in label:
                # check the list and remove the worst matching occurence if there are 2 or more
                if len(occurences) > 1:
                    lev = []
                    for occurence in occurences:
                        lev.append(Levenshtein.distance(oc, occurence[0]))
                    #print("lev : ", lev)
                    # if all elements are equal, continue
                    if lev.count(lev[0]) != len(lev):
                        worst = lev.index(max(lev))
                        if worst != -1:
                            occurences.pop(worst)

                for occurence in occurences:
                    for key in positions.keys():
                        if key in labels_act[act][paragraph].keys():
                            begin = positions[key]
                            end = positions[key] + label_length[key]
                            if occurence[1] >= begin and occurence[1] <= end:
                                print("Occurence :", occurence[0], "Position :", occurence[1], "Key :", key, "Begin :", begin, "End :", end)
                                occurences.remove(occurence)

            if 'mere-mariee' in label:
                if label == 'Prenom-mere-mariee':
                    positions['Prenom-mere-mariee'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-mere-mariee':
                #     positions['Nom-mere-mariee'] = occurences[0][1]
                #     return occurences[0]

                p = positions['Prenom-mere-mariee'] if (
                    'Prenom-mere-mariee' in positions.keys()) else 0

                # choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        positions[label] = occ[1]
                        return occ

                # si aucune occurence après p, choisir la dernière occurence
                positions[label] = occurences[-1][1]
                return occurences[-1]

            if 'pere-mariee' in label:
                if label == 'Prenom-pere-mariee':
                    positions['Prenom-pere-mariee'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-pere-mariee':
                #     positions['Nom-pere-mariee'] = occurences[0][1]
                #     return occurences[0]

                p = positions['Prenom-pere-mariee'] if (
                    'Prenom-pere-mariee' in positions.keys()) else 0

                # choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        positions[label] = occ[1]
                        return occ

                # si aucune occurence après p, choisir la dernière occurence
                positions[label] = occurences[-1][1]
                return occurences[-1]

            if 'mere-mari' in label:
                if label == 'Prenom-mere-mari':
                    positions['Prenom-mere-mari'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-mere-mari':
                #     positions['Nom-mere-mari'] = occurences[0][1]
                #     return occurences[0]

                p = positions['Prenom-mere-mari'] if (
                    'Prenom-mere-mari' in positions.keys()) else 0

                # choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        positions[label] = occ[1]
                        return occ

                # si aucune occurence après p, choisir la dernière occurence
                positions[label] = occurences[-1][1]
                return occurences[-1]

            if 'pere-mari' in label:
                if label == 'Prenom-pere-mari':
                    positions['Prenom-pere-mari'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-pere-mari':
                #     positions['Nom-pere-mari'] = occurences[0][1]
                #     return occurences[0]

                p = positions['Prenom-pere-mari'] if (
                    'Prenom-pere-mari' in positions.keys()) else 0

                # choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        positions[label] = occ[1]
                        return occ

                # si aucune occurence après p, choisir la dernière occurence
                positions[label] = occurences[-1][1]
                return occurences[-1]

            if 'temoin-2' in label:
                if label == 'Prenom-temoin-2':
                    positions['Prenom-temoin-2'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-temoin-2':
                #     positions['Nom-temoin-2'] = occurences[0][1]
                #     return occurences[0]

                p = positions['Prenom-temoin-2'] if (
                    'Prenom-temoin-2' in positions.keys()) else 0

                # choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        positions[label] = occ[1]
                        return occ

                # si aucune occurence après p, choisir la dernière occurence
                positions[label] = occurences[-1][1]
                return occurences[-1]

            positions[label] = occurences[0][1]
            return occurences[0]

        good_occ, pos = search_best_position(occurences)
        print(positions)
        def update_positions(pos, len_after, len_before, positions = positions):
            for label, position in positions.items():
                for paragraph in labels_act['archives_AD075EC_11M549_0094-right.png-0'].keys():
                    if label in labels_act['archives_AD075EC_11M549_0094-right.png-0'][paragraph].keys():
                        if position > pos:
                            positions[label] += len_after + len_before

        # I want to insert emojis around the occurence, I want this to be done only for good_occ
        text = text[:pos] + emojis['begin'] + good_occ + \
            emojis['end'] + text[pos+len(good_occ):]
        
        # update positions
        label_length[label] = len(good_occ) + len(emojis['begin']) + len(emojis['end'])
        update_positions(pos, len(emojis['begin']), len(emojis['end']))

        #print("Text :", text)
        return text

def fix_pluriels(text, pluriels = questions_dict):
    for paragraph, txt in text.items():

        #Mariee + 2 parents
        txt = txt.replace('👰🏠🌇👰👴🏠🌇👰👵🏠🌇', pluriels['Ville-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌉👧🎩🏡🌉👧🏡🌉', pluriels['Ville-residence-parents-mariee']['end'])
        txt = txt.replace('👰🏠🗺👰👴🏠🗺👰👵🏠🗺', pluriels['Departement-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡📌👧🎩🏡📌👧🏡📌', pluriels['Departement-residence-parents-mariee']['end'])
        txt = txt.replace('👰🏠🏳👰👴🏠🏳👰👵🏠🏳', pluriels['Pays-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌍👧🎩🏡🌍👧🏡🌍', pluriels['Pays-residence-parents-mariee']['end'])
        txt = txt.replace('👰🏠🔟👰👴🏠🔟👰👵🏠🔟', pluriels['Numero-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔢👧🎩🏡🔢👧🏡🔢', pluriels['Numero-rue-residence-parents-mariee']['end'])
        txt = txt.replace('👰🏠🛣👰👴🏠🛣👰👵🏠🛣', pluriels['Type-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🛤👧🎩🏡🛤👧🏡🛤', pluriels['Type-rue-residence-parents-mariee']['end'])
        txt = txt.replace('👰🏠🔠👰👴🏠🔠👰👵🏠🔠', pluriels['Nom-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔡👧🎩🏡🔡👧🏡🔡', pluriels['Nom-rue-residence-parents-mariee']['end'])

        #Mariee + mere
        txt = txt.replace('👰🏠🌇👰👵🏠🌇', pluriels['Ville-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌉👧🏡🌉', pluriels['Ville-residence-mere-mariee']['end'])
        txt = txt.replace('👰🏠🗺👰👵🏠🗺', pluriels['Departement-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡📌👧🏡📌', pluriels['Departement-residence-mere-mariee']['end'])
        txt = txt.replace('👰🏠🏳👰👵🏠🏳', pluriels['Pays-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌍👧🏡🌍', pluriels['Pays-residence-mere-mariee']['end'])
        txt = txt.replace('👰🏠🔟👰👵🏠🔟', pluriels['Numero-rue-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔢👧🏡🔢', pluriels['Numero-rue-residence-mere-mariee']['end'])
        txt = txt.replace('👰🏠🛣👰👵🏠🛣', pluriels['Type-rue-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡🛤👧🏡🛤', pluriels['Type-rue-residence-mere-mariee']['end'])
        txt = txt.replace('👰🏠🔠👰👵🏠🔠', pluriels['Nom-rue-residence-mere-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔡👧🏡🔡', pluriels['Nom-rue-residence-mere-mariee']['end'])

        #Mariee + pere
        txt = txt.replace('👰🏠🌇👰👴🏠🌇', pluriels['Ville-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡🌉👧🏡🌉', pluriels['Ville-residence-pere-mariee']['end'])
        txt = txt.replace('👰🏠🗺👰👴🏠🗺', pluriels['Departement-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡📌👧🏡📌', pluriels['Departement-residence-pere-mariee']['end'])
        txt = txt.replace('👰🏠🏳👰👴🏠🏳', pluriels['Pays-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡🌍👧🏡🌍', pluriels['Pays-residence-pere-mariee']['end'])
        txt = txt.replace('👰🏠🔟👰👴🏠🔟', pluriels['Numero-rue-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡🔢👧🏡🔢', pluriels['Numero-rue-residence-pere-mariee']['end'])
        txt = txt.replace('👰🏠🛣👰👴🏠🛣', pluriels['Type-rue-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡🛤👧🏡🛤', pluriels['Type-rue-residence-pere-mariee']['end'])
        txt = txt.replace('👰🏠🔠👰👴🏠🔠', pluriels['Nom-rue-residence-pere-mariee']['begin'])
        txt = txt.replace('👧🎩🏡🔡👧🏡🔡', pluriels['Nom-rue-residence-pere-mariee']['end'])

        #Parents mariee seuls
        txt = txt.replace('👰👴🏠🌇👰👵🏠🌇', pluriels['Ville-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌉👧🎩🏡🌉', pluriels['Ville-residence-parents-mariee']['end'])
        txt = txt.replace('👰👴🏠🗺👰👵🏠🗺', pluriels['Departement-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡📌👧🎩🏡📌', pluriels['Departement-residence-parents-mariee']['end'])
        txt = txt.replace('👰👴🏠🏳👰👵🏠🏳', pluriels['Pays-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🌍👧🎩🏡🌍', pluriels['Pays-residence-parents-mariee']['end'])
        txt = txt.replace('👰👴🏠🔟👰👵🏠🔟', pluriels['Numero-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔢👧🎩🏡🔢', pluriels['Numero-rue-residence-parents-mariee']['end'])
        txt = txt.replace('👰👴🏠🛣👰👵🏠🛣', pluriels['Type-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🛤👧🎩🏡🛤', pluriels['Type-rue-residence-parents-mariee']['end'])
        txt = txt.replace('👰👴🏠🔠👰👵🏠🔠', pluriels['Nom-rue-residence-parents-mariee']['begin'])
        txt = txt.replace('👧👒🏡🔡👧🎩🏡🔡', pluriels['Nom-rue-residence-parents-mariee']['end'])

        txt = txt.replace('👰👴🔧👰👵🔧', pluriels['Profession-parents-mariee']['begin'])
        txt = txt.replace('👧👒🪛👧🎩🪛', pluriels['Profession-parents-mariee']['end'])

        #mari + 2 parents
        txt = txt.replace('👨🏠🌇👨👴🏠🌇👨👵🏠🌇', pluriels['Ville-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🌉👦🎩🏡🌉👦🏡🌉', pluriels['Ville-residence-parents-mari']['end'])
        txt = txt.replace('👨🏠🗺👨👴🏠🗺👨👵🏠🗺', pluriels['Departement-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡📌👦🎩🏡📌👦🏡📌', pluriels['Departement-residence-parents-mari']['end'])
        txt = txt.replace('👨🏠🏳👨👴🏠🏳👨👵🏠🏳', pluriels['Pays-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🌍👦🎩🏡🌍👦🏡🌍', pluriels['Pays-residence-parents-mari']['end'])
        txt = txt.replace('👨🏠🔟👨👴🏠🔟👨👵🏠🔟', pluriels['Numero-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🔢👦🎩🏡🔢👦🏡🔢', pluriels['Numero-rue-residence-parents-mari']['end'])
        txt = txt.replace('👨🏠🛣👨👴🏠🛣👨👵🏠🛣', pluriels['Type-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🛤👦🎩🏡🛤👦🏡🛤', pluriels['Type-rue-residence-parents-mari']['end'])
        txt = txt.replace('👨🏠🔠👨👴🏠🔠👨👵🏠🔠', pluriels['Nom-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🔡👦🎩🏡🔡👦🏡🔡', pluriels['Nom-rue-residence-parents-mari']['end'])

        #mari + mere
        txt = txt.replace('👨🏠🌇👨👵🏠🌇', pluriels['Ville-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡🌉👦🏡🌉', pluriels['Ville-residence-mere-mari']['end'])
        txt = txt.replace('👨🏠🗺👨👵🏠🗺', pluriels['Departement-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡📌👦🏡📌', pluriels['Departement-residence-mere-mari']['end'])
        txt = txt.replace('👨🏠🏳👨👵🏠🏳', pluriels['Pays-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡🌍👦🏡🌍', pluriels['Pays-residence-mere-mari']['end'])
        txt = txt.replace('👨🏠🔟👨👵🏠🔟', pluriels['Numero-rue-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡🔢👦🏡🔢', pluriels['Numero-rue-residence-mere-mari']['end'])
        txt = txt.replace('👨🏠🛣👨👵🏠🛣', pluriels['Type-rue-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡🛤👦🏡🛤', pluriels['Type-rue-residence-mere-mari']['end'])
        txt = txt.replace('👨🏠🔠👨👵🏠🔠', pluriels['Nom-rue-residence-mere-mari']['begin'])
        txt = txt.replace('👦👒🏡🔡👦🏡🔡', pluriels['Nom-rue-residence-mere-mari']['end'])

        #mari + pere
        txt = txt.replace('👨🏠🌇👨👴🏠🌇', pluriels['Ville-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡🌉👦🏡🌉', pluriels['Ville-residence-pere-mari']['end'])
        txt = txt.replace('👨🏠🗺👨👴🏠🗺', pluriels['Departement-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡📌👦🏡📌', pluriels['Departement-residence-pere-mari']['end'])
        txt = txt.replace('👨🏠🏳👨👴🏠🏳', pluriels['Pays-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡🌍👦🏡🌍', pluriels['Pays-residence-pere-mari']['end'])
        txt = txt.replace('👨🏠🔟👨👴🏠🔟', pluriels['Numero-rue-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡🔢👦🏡🔢', pluriels['Numero-rue-residence-pere-mari']['end'])
        txt = txt.replace('👨🏠🛣👨👴🏠🛣', pluriels['Type-rue-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡🛤👦🏡🛤', pluriels['Type-rue-residence-pere-mari']['end'])
        txt = txt.replace('👨🏠🔠👨👴🏠🔠', pluriels['Nom-rue-residence-pere-mari']['begin'])
        txt = txt.replace('👦🎩🏡🔡👦🏡🔡', pluriels['Nom-rue-residence-pere-mari']['end'])

        #Parents mari seuls
        txt = txt.replace('👨👴🏠🌇👨👵🏠🌇', pluriels['Ville-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🌉👦🎩🏡🌉', pluriels['Ville-residence-parents-mari']['end'])
        txt = txt.replace('👨👴🏠🗺👨👵🏠🗺', pluriels['Departement-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡📌👦🎩🏡📌', pluriels['Departement-residence-parents-mari']['end'])
        txt = txt.replace('👨👴🏠🏳👨👵🏠🏳', pluriels['Pays-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🌍👦🎩🏡🌍', pluriels['Pays-residence-parents-mari']['end'])
        txt = txt.replace('👨👴🏠🔟👨👵🏠🔟', pluriels['Numero-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🔢👦🎩🏡🔢', pluriels['Numero-rue-residence-parents-mari']['end'])
        txt = txt.replace('👨👴🏠🛣👨👵🏠🛣', pluriels['Type-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🛤👦🎩🏡🛤', pluriels['Type-rue-residence-parents-mari']['end'])
        txt = txt.replace('👨👴🏠🔠👨👵🏠🔠', pluriels['Nom-rue-residence-parents-mari']['begin'])
        txt = txt.replace('👦👒🏡🔡👦🎩🏡🔡', pluriels['Nom-rue-residence-parents-mari']['end'])

        txt = txt.replace('👨👴🔧👨👵🔧', pluriels['Profession-parents-mari']['begin'])
        txt = txt.replace('👦👒🪛👦🎩🪛', pluriels['Profession-parents-mari']['end'])
        #print(txt)
    
        text[paragraph] = txt

    return text

# %%
from rich import print
for paragraph, labels  in labels_act["archives_AD075EC_11M549_0094-right.png-0"].items():
    text[paragraph] = text[paragraph].replace("-\n", "").replace("\n", " ")
    for key, label in labels.items():
        if label != "":
            #print("\n\n")
            text[paragraph] = insert_emojis_around_label(key, paragraph, text[paragraph])
            #print(text[paragraph])
            #print("\n\n")
final = fix_pluriels(text)
for paragraph, txt in final.items():
    print(txt)
    print("\n\n")
# Out:
# Key : Jour-mariage Ref : vingt-huit Occurences :
# [('vingt-huit', 3)]
# {'Jour-mariage': 3}
# Key : Mois-mariage Ref : juin Occurences :
# [('juin', 18)]
# {'Jour-mariage': 3, 'Mois-mariage': 18}
# Key : Annee-mariage Ref : mil neuf cent trente Occurences :
# [('mil neuf cent trente', 27)]
# {'Jour-mariage': 3, 'Mois-mariage': 18, 'Annee-mariage': 27}
# Key : Heure-mariage Ref : douze heures Occurences :
# [('douze heures', 53)]
# {'Jour-mariage': 3, 'Mois-mariage': 18, 'Annee-mariage': 27, 'Heure-mariage': 53}
# Key : Minute-mariage Ref : douze minutes Occurences :
# [('douze minutes', 70)]
# {'Jour-mariage': 3, 'Mois-mariage': 18, 'Annee-mariage': 27, 'Heure-mariage': 53, 'Minute-mariage': 70}
# Key : Prenom-mari Ref : Gilbert Alexandre Jean Occurences :
# [('Gilbert Alexandre Jean', 1)]
# {
#     'Jour-mariage': 3,
#     'Mois-mariage': 18,
#     'Annee-mariage': 27,
#     'Heure-mariage': 53,
#     'Minute-mariage': 70,
#     'Prenom-mari': 1
# }
# Key : Nom-mari Ref : VALO Occurences :
# [('VALO', 28), ('VALO', 198)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 31,
#     'Heure-mariage': 57,
#     'Minute-mariage': 74,
#     'Prenom-mari': 1,
#     'Nom-mari': 28
# }
# Key : Profession-mari Ref : fraiseur Occurences :
# [('fraiseur', 38)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 35,
#     'Heure-mariage': 61,
#     'Minute-mariage': 78,
#     'Prenom-mari': 1,
#     'Nom-mari': 28,
#     'Profession-mari': 38
# }
# Key : Ville-naissance-mari Ref : Saint Aubin des Bois Occurences :
# [('Saint Aubin des Bois', 56)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 35,
#     'Heure-mariage': 65,
#     'Minute-mariage': 82,
#     'Prenom-mari': 1,
#     'Nom-mari': 28,
#     'Profession-mari': 38,
#     'Ville-naissance-mari': 56
# }
# Key : Departement-naissance-mari Ref : Eure et Loir Occurences :
# [('Eure et Loir', 85), ('Eure et Loir', 305)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 35,
#     'Heure-mariage': 71,
#     'Minute-mariage': 88,
#     'Prenom-mari': 1,
#     'Nom-mari': 28,
#     'Profession-mari': 38,
#     'Ville-naissance-mari': 56,
#     'Departement-naissance-mari': 85
# }
# Key : Jour-naissance-mari Ref : vingt-huit Occurences :
# [('vingt-huit', 109)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 35,
#     'Heure-mariage': 71,
#     'Minute-mariage': 94,
#     'Prenom-mari': 1,
#     'Nom-mari': 28,
#     'Profession-mari': 38,
#     'Ville-naissance-mari': 56,
#     'Departement-naissance-mari': 85,
#     'Jour-naissance-mari': 109
# }
# Key : Mois-naissance-mari Ref : février Occurences :
# [('février', 126)]
# {
#     'Jour-mariage': 7,
#     'Mois-mariage': 22,
#     'Annee-mariage': 35,
#     'Heure-mariage': 71,
#     'Minute-mariage': 94,
#     'Prenom-mari': 1,
#     'Nom-mari': 28,
#     'Profession-mari': 38,
#     'Ville-naissance-mari': 56,
#     'Departement-naissance-mari': 85,
#     'Jour-naissance-mari': 109,
#     'Mois-naissance-mari': 126
# }
# Key : Annee-naissance-mari Ref : mil neuf cent-huit Occurences :
# [('mil neuf cent-huit', 140)]
# {
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 191,
#     'Nom-rue-residence-mariee': 201,
#     'Prenom-pere-mariee': 255,
#     'Nom-pere-mariee': 276
# }
# Key : Profession-pere-mariee Ref : tourneur Occurences :
# [('tourneur', 290)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 186,
#     'Age-mari': 224,
#     'Numero-rue-residence-mari': 254,
#     'Type-rue-residence-mari': 270,
#     'Nom-rue-residence-mari': 286,
#     'Prenom-pere-mari': 310,
#     'Nom-pere-mari': 334,
#     'Prenom-mere-mari': 358,
#     'Nom-mere-mari': 379,
#     'Profession-mere-mari': 406,
#     'Ville-residence-mere-mari': 438,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 191,
#     'Nom-rue-residence-mariee': 201,
#     'Prenom-pere-mariee': 255,
#     'Nom-pere-mariee': 276,
#     'Profession-pere-mariee': 290
# }
# Key : Numero-rue-residence-pere-mariee Ref : 151 bis Occurences :
# [('151 bis', 180)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 186,
#     'Age-mari': 224,
#     'Numero-rue-residence-mari': 254,
#     'Type-rue-residence-mari': 270,
#     'Nom-rue-residence-mari': 286,
#     'Prenom-pere-mari': 316,
#     'Nom-pere-mari': 340,
#     'Prenom-mere-mari': 364,
#     'Nom-mere-mari': 385,
#     'Profession-mere-mari': 412,
#     'Ville-residence-mere-mari': 444,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 191,
#     'Nom-rue-residence-mariee': 201,
#     'Prenom-pere-mariee': 255,
#     'Nom-pere-mariee': 276,
#     'Profession-pere-mariee': 290,
#     'Numero-rue-residence-pere-mariee': 180
# }
# Key : Type-rue-residence-pere-mariee Ref : rue Occurences :
# [('rue', 202)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 232,
#     'Numero-rue-residence-mari': 262,
#     'Type-rue-residence-mari': 278,
#     'Nom-rue-residence-mari': 294,
#     'Prenom-pere-mari': 324,
#     'Nom-pere-mari': 348,
#     'Prenom-mere-mari': 372,
#     'Nom-mere-mari': 393,
#     'Profession-mere-mari': 420,
#     'Ville-residence-mere-mari': 452,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 209,
#     'Prenom-pere-mariee': 263,
#     'Nom-pere-mariee': 284,
#     'Profession-pere-mariee': 298,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202
# }
# Key : Nom-rue-residence-pere-mariee Ref : de la Roquette Occurences :
# [('de la Roquette', 220)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 240,
#     'Numero-rue-residence-mari': 270,
#     'Type-rue-residence-mari': 286,
#     'Nom-rue-residence-mari': 302,
#     'Prenom-pere-mari': 332,
#     'Nom-pere-mari': 356,
#     'Prenom-mere-mari': 380,
#     'Nom-mere-mari': 401,
#     'Profession-mere-mari': 428,
#     'Ville-residence-mere-mari': 460,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 217,
#     'Prenom-pere-mariee': 271,
#     'Nom-pere-mariee': 292,
#     'Profession-pere-mariee': 306,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202,
#     'Nom-rue-residence-pere-mariee': 220
# }
# Key : Prenom-mere-mariee Ref : Marie Occurences :
# [('Marcelle', 5), ('Marie', 336)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 248,
#     'Numero-rue-residence-mari': 278,
#     'Type-rue-residence-mari': 294,
#     'Nom-rue-residence-mari': 310,
#     'Prenom-pere-mari': 340,
#     'Nom-pere-mari': 364,
#     'Prenom-mere-mari': 388,
#     'Nom-mere-mari': 409,
#     'Profession-mere-mari': 436,
#     'Ville-residence-mere-mari': 468,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 217,
#     'Prenom-pere-mariee': 279,
#     'Nom-pere-mariee': 300,
#     'Profession-pere-mariee': 314,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202,
#     'Nom-rue-residence-pere-mariee': 220,
#     'Prenom-mere-mariee': 336
# }
# Key : Nom-mere-mariee Ref : BACHELET Occurences :
# [('BACHELET', 348)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 248,
#     'Numero-rue-residence-mari': 278,
#     'Type-rue-residence-mari': 294,
#     'Nom-rue-residence-mari': 310,
#     'Prenom-pere-mari': 346,
#     'Nom-pere-mari': 370,
#     'Prenom-mere-mari': 394,
#     'Nom-mere-mari': 415,
#     'Profession-mere-mari': 442,
#     'Ville-residence-mere-mari': 474,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 217,
#     'Prenom-pere-mariee': 279,
#     'Nom-pere-mariee': 300,
#     'Profession-pere-mariee': 314,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202,
#     'Nom-rue-residence-pere-mariee': 220,
#     'Prenom-mere-mariee': 336,
#     'Nom-mere-mariee': 348
# }
# Key : Profession-mere-mariee Ref : couturière Occurences :
# [('couturière', 39), ('couturière', 376)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 248,
#     'Numero-rue-residence-mari': 278,
#     'Type-rue-residence-mari': 294,
#     'Nom-rue-residence-mari': 310,
#     'Prenom-pere-mari': 346,
#     'Nom-pere-mari': 376,
#     'Prenom-mere-mari': 400,
#     'Nom-mere-mari': 421,
#     'Profession-mere-mari': 448,
#     'Ville-residence-mere-mari': 480,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 217,
#     'Prenom-pere-mariee': 279,
#     'Nom-pere-mariee': 300,
#     'Profession-pere-mariee': 314,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202,
#     'Nom-rue-residence-pere-mariee': 220,
#     'Prenom-mere-mariee': 336,
#     'Nom-mere-mariee': 348,
#     'Profession-mere-mariee': 376
# }
# Key : Numero-rue-residence-mere-mariee Ref : 151 bis Occurences :
# [('151 bis', 184)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 194,
#     'Age-mari': 248,
#     'Numero-rue-residence-mari': 278,
#     'Type-rue-residence-mari': 294,
#     'Nom-rue-residence-mari': 310,
#     'Prenom-pere-mari': 346,
#     'Nom-pere-mari': 376,
#     'Prenom-mere-mari': 406,
#     'Nom-mere-mari': 427,
#     'Profession-mere-mari': 454,
#     'Ville-residence-mere-mari': 486,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 199,
#     'Nom-rue-residence-mariee': 217,
#     'Prenom-pere-mariee': 279,
#     'Nom-pere-mariee': 300,
#     'Profession-pere-mariee': 314,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 202,
#     'Nom-rue-residence-pere-mariee': 220,
#     'Prenom-mere-mariee': 336,
#     'Nom-mere-mariee': 348,
#     'Profession-mere-mariee': 376,
#     'Numero-rue-residence-mere-mariee': 184
# }
# Key : Type-rue-residence-mere-mariee Ref : rue Occurences :
# [('rue', 214)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 202,
#     'Age-mari': 256,
#     'Numero-rue-residence-mari': 286,
#     'Type-rue-residence-mari': 302,
#     'Nom-rue-residence-mari': 318,
#     'Prenom-pere-mari': 354,
#     'Nom-pere-mari': 384,
#     'Prenom-mere-mari': 414,
#     'Nom-mere-mari': 435,
#     'Profession-mere-mari': 462,
#     'Ville-residence-mere-mari': 494,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 207,
#     'Nom-rue-residence-mariee': 225,
#     'Prenom-pere-mariee': 287,
#     'Nom-pere-mariee': 308,
#     'Profession-pere-mariee': 322,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 210,
#     'Nom-rue-residence-pere-mariee': 228,
#     'Prenom-mere-mariee': 344,
#     'Nom-mere-mariee': 356,
#     'Profession-mere-mariee': 384,
#     'Numero-rue-residence-mere-mariee': 184,
#     'Type-rue-residence-mere-mariee': 214
# }
# Key : Nom-rue-residence-mere-mariee Ref : de la Roquette Occurences :
# [('de la Roquette', 240)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 1,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 202,
#     'Age-mari': 264,
#     'Numero-rue-residence-mari': 294,
#     'Type-rue-residence-mari': 310,
#     'Nom-rue-residence-mari': 326,
#     'Prenom-pere-mari': 362,
#     'Nom-pere-mari': 392,
#     'Prenom-mere-mari': 422,
#     'Nom-mere-mari': 443,
#     'Profession-mere-mari': 470,
#     'Ville-residence-mere-mari': 502,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 207,
#     'Nom-rue-residence-mariee': 233,
#     'Prenom-pere-mariee': 295,
#     'Nom-pere-mariee': 316,
#     'Profession-pere-mariee': 330,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 210,
#     'Nom-rue-residence-pere-mariee': 236,
#     'Prenom-mere-mariee': 352,
#     'Nom-mere-mariee': 364,
#     'Profession-mere-mariee': 392,
#     'Numero-rue-residence-mere-mariee': 184,
#     'Type-rue-residence-mere-mariee': 214,
#     'Nom-rue-residence-mere-mariee': 240
# }
# Key : Prenom-mari Ref : Gilbert Alexandre Jean Occurences :
# [('Gilbert Alexandre Jean', 141)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 141,
#     'Nom-mari': 52,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 145,
#     'Mois-naissance-mari': 166,
#     'Annee-naissance-mari': 202,
#     'Age-mari': 272,
#     'Numero-rue-residence-mari': 302,
#     'Type-rue-residence-mari': 318,
#     'Nom-rue-residence-mari': 334,
#     'Prenom-pere-mari': 370,
#     'Nom-pere-mari': 400,
#     'Prenom-mere-mari': 430,
#     'Nom-mere-mari': 451,
#     'Profession-mere-mari': 478,
#     'Ville-residence-mere-mari': 510,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 151,
#     'Numero-rue-residence-mariee': 177,
#     'Type-rue-residence-mariee': 207,
#     'Nom-rue-residence-mariee': 233,
#     'Prenom-pere-mariee': 303,
#     'Nom-pere-mariee': 324,
#     'Profession-pere-mariee': 338,
#     'Numero-rue-residence-pere-mariee': 180,
#     'Type-rue-residence-pere-mariee': 210,
#     'Nom-rue-residence-pere-mariee': 236,
#     'Prenom-mere-mariee': 360,
#     'Nom-mere-mariee': 372,
#     'Profession-mere-mariee': 400,
#     'Numero-rue-residence-mere-mariee': 184,
#     'Type-rue-residence-mere-mariee': 214,
#     'Nom-rue-residence-mere-mariee': 240
# }
# Key : Nom-mari Ref : VALO Occurences :
# [('VALO', 168)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 141,
#     'Nom-mari': 168,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 149,
#     'Mois-naissance-mari': 170,
#     'Annee-naissance-mari': 206,
#     'Age-mari': 276,
#     'Numero-rue-residence-mari': 306,
#     'Type-rue-residence-mari': 322,
#     'Nom-rue-residence-mari': 338,
#     'Prenom-pere-mari': 374,
#     'Nom-pere-mari': 404,
#     'Prenom-mere-mari': 434,
#     'Nom-mere-mari': 455,
#     'Profession-mere-mari': 482,
#     'Ville-residence-mere-mari': 514,
#     'Prenom-mariee': 3,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 155,
#     'Numero-rue-residence-mariee': 181,
#     'Type-rue-residence-mariee': 211,
#     'Nom-rue-residence-mariee': 237,
#     'Prenom-pere-mariee': 307,
#     'Nom-pere-mariee': 328,
#     'Profession-pere-mariee': 342,
#     'Numero-rue-residence-pere-mariee': 184,
#     'Type-rue-residence-pere-mariee': 214,
#     'Nom-rue-residence-pere-mariee': 240,
#     'Prenom-mere-mariee': 364,
#     'Nom-mere-mariee': 376,
#     'Profession-mere-mariee': 404,
#     'Numero-rue-residence-mere-mariee': 188,
#     'Type-rue-residence-mere-mariee': 218,
#     'Nom-rue-residence-mere-mariee': 244
# }
# Key : Prenom-mariee Ref : Marcelle Fernande Occurences :
# [('Marcelle Fernande', 180)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Prenom-mari': 141,
#     'Nom-mari': 168,
#     'Profession-mari': 50,
#     'Ville-naissance-mari': 74,
#     'Departement-naissance-mari': 109,
#     'Jour-naissance-mari': 149,
#     'Mois-naissance-mari': 174,
#     'Annee-naissance-mari': 210,
#     'Age-mari': 280,
#     'Numero-rue-residence-mari': 310,
#     'Type-rue-residence-mari': 326,
#     'Nom-rue-residence-mari': 342,
#     'Prenom-pere-mari': 378,
#     'Nom-pere-mari': 408,
#     'Prenom-mere-mari': 438,
#     'Nom-mere-mari': 459,
#     'Profession-mere-mari': 486,
#     'Ville-residence-mere-mari': 518,
#     'Prenom-mariee': 180,
#     'Nom-mariee': 25,
#     'Profession-mariee': 37,
#     'Ville-naissance-mariee': 59,
#     'Jour-naissance-mariee': 95,
#     'Mois-naissance-mariee': 112,
#     'Annee-naissance-mariee': 126,
#     'Age-mariee': 155,
#     'Numero-rue-residence-mariee': 185,
#     'Type-rue-residence-mariee': 215,
#     'Nom-rue-residence-mariee': 241,
#     'Prenom-pere-mariee': 311,
#     'Nom-pere-mariee': 332,
#     'Profession-pere-mariee': 346,
#     'Numero-rue-residence-pere-mariee': 188,
#     'Type-rue-residence-pere-mariee': 218,
#     'Nom-rue-residence-pere-mariee': 244,
#     'Prenom-mere-mariee': 368,
#     'Nom-mere-mariee': 380,
#     'Profession-mere-mariee': 408,
#     'Numero-rue-residence-mere-mariee': 192,
#     'Type-rue-residence-mere-mariee': 222,
#     'Nom-rue-residence-mere-mariee': 248
# }
# Key : Nom-mariee Ref : WENDER- Occurences :
# [(' WENDER', 201)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 30,
#     'Annee-mariage': 47,
#     'Heure-mariage': 89,
#     'Minute-mariage': 124,
#     'Ville-naissance-mariee': 67,
#     'Jour-naissance-mariee': 103,
#     'Mois-naissance-mariee': 120,
#     'Annee-naissance-mariee': 134,
#     'Age-mariee': 163,
#     'Numero-rue-residence-mariee': 197,
#     'Type-rue-residence-mariee': 231,
#     'Nom-rue-residence-mariee': 257,
#     'Prenom-pere-mariee': 327,
#     'Nom-pere-mariee': 348,
#     'Profession-pere-mariee': 362,
#     'Numero-rue-residence-pere-mariee': 200,
#     'Type-rue-residence-pere-mariee': 234,
#     'Nom-rue-residence-pere-mariee': 260,
#     'Prenom-mere-mariee': 384,
#     'Nom-mere-mariee': 396,
#     'Profession-mere-mariee': 424,
#     'Numero-rue-residence-mere-mariee': 204,
#     'Type-rue-residence-mere-mariee': 238,
#     'Nom-rue-residence-mere-mariee': 264,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43
# }
# Key : Numero-rue-residence-temoin-1 Ref : 114 Occurences :
# [('114', 77)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 38,
#     'Annee-mariage': 59,
#     'Heure-mariage': 101,
#     'Minute-mariage': 136,
#     'Prenom-mari': 165,
#     'Nom-mari': 192,
#     'Profession-mari': 62,
#     'Ville-naissance-mari': 86,
#     'Departement-naissance-mari': 121,
#     'Jour-naissance-mari': 161,
#     'Mois-naissance-mari': 186,
#     'Annee-naissance-mari': 230,
#     'Age-mari': 300,
#     'Numero-rue-residence-mari': 330,
#     'Type-rue-residence-mari': 346,
#     'Nom-rue-residence-mari': 362,
#     'Prenom-pere-mari': 398,
#     'Nom-pere-mari': 428,
#     'Prenom-mere-mari': 458,
#     'Nom-mere-mari': 479,
#     'Profession-mere-mari': 506,
#     'Ville-residence-mere-mari': 538,
#     'Prenom-mariee': 204,
#     'Nom-mariee': 225,
#     'Profession-mariee': 49,
#     'Ville-naissance-mariee': 71,
#     'Jour-naissance-mariee': 107,
#     'Mois-naissance-mariee': 124,
#     'Annee-naissance-mariee': 138,
#     'Age-mariee': 167,
#     'Numero-rue-residence-mariee': 201,
#     'Type-rue-residence-mariee': 235,
#     'Nom-rue-residence-mariee': 261,
#     'Prenom-pere-mariee': 331,
#     'Nom-pere-mariee': 352,
#     'Profession-pere-mariee': 366,
#     'Numero-rue-residence-pere-mariee': 204,
#     'Type-rue-residence-pere-mariee': 238,
#     'Nom-rue-residence-pere-mariee': 264,
#     'Prenom-mere-mariee': 388,
#     'Nom-mere-mariee': 400,
#     'Profession-mere-mariee': 428,
#     'Numero-rue-residence-mere-mariee': 208,
#     'Type-rue-residence-mere-mariee': 242,
#     'Nom-rue-residence-mere-mariee': 268,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43,
#     'Numero-rue-residence-temoin-1': 77
# }
# Key : Type-rue-residence-temoin-1 Ref : rue Occurences :
# [('rue', 87), ('rue', 210)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 38,
#     'Annee-mariage': 59,
#     'Heure-mariage': 107,
#     'Minute-mariage': 142,
#     'Prenom-mari': 177,
#     'Nom-mari': 204,
#     'Profession-mari': 62,
#     'Ville-naissance-mari': 92,
#     'Departement-naissance-mari': 127,
#     'Jour-naissance-mari': 167,
#     'Mois-naissance-mari': 192,
#     'Annee-naissance-mari': 236,
#     'Age-mari': 306,
#     'Numero-rue-residence-mari': 336,
#     'Type-rue-residence-mari': 352,
#     'Nom-rue-residence-mari': 368,
#     'Prenom-pere-mari': 404,
#     'Nom-pere-mari': 434,
#     'Prenom-mere-mari': 464,
#     'Nom-mere-mari': 485,
#     'Profession-mere-mari': 512,
#     'Ville-residence-mere-mari': 544,
#     'Prenom-mariee': 216,
#     'Nom-mariee': 237,
#     'Profession-mariee': 49,
#     'Ville-naissance-mariee': 71,
#     'Jour-naissance-mariee': 113,
#     'Mois-naissance-mariee': 130,
#     'Annee-naissance-mariee': 144,
#     'Age-mariee': 173,
#     'Numero-rue-residence-mariee': 207,
#     'Type-rue-residence-mariee': 241,
#     'Nom-rue-residence-mariee': 267,
#     'Prenom-pere-mariee': 337,
#     'Nom-pere-mariee': 358,
#     'Profession-pere-mariee': 372,
#     'Numero-rue-residence-pere-mariee': 210,
#     'Type-rue-residence-pere-mariee': 244,
#     'Nom-rue-residence-pere-mariee': 270,
#     'Prenom-mere-mariee': 394,
#     'Nom-mere-mariee': 406,
#     'Profession-mere-mariee': 434,
#     'Numero-rue-residence-mere-mariee': 214,
#     'Type-rue-residence-mere-mariee': 248,
#     'Nom-rue-residence-mere-mariee': 274,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43,
#     'Numero-rue-residence-temoin-1': 77,
#     'Type-rue-residence-temoin-1': 87
# }
# Key : Nom-rue-residence-temoin-1 Ref : Jean Jaurès Occurences :
# [('Jean Jaurès', 97)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 38,
#     'Annee-mariage': 59,
#     'Heure-mariage': 113,
#     'Minute-mariage': 148,
#     'Prenom-mari': 189,
#     'Nom-mari': 216,
#     'Profession-mari': 62,
#     'Ville-naissance-mari': 98,
#     'Departement-naissance-mari': 133,
#     'Jour-naissance-mari': 173,
#     'Mois-naissance-mari': 198,
#     'Annee-naissance-mari': 242,
#     'Age-mari': 312,
#     'Numero-rue-residence-mari': 342,
#     'Type-rue-residence-mari': 358,
#     'Nom-rue-residence-mari': 374,
#     'Prenom-pere-mari': 410,
#     'Nom-pere-mari': 440,
#     'Prenom-mere-mari': 470,
#     'Nom-mere-mari': 491,
#     'Profession-mere-mari': 518,
#     'Ville-residence-mere-mari': 550,
#     'Prenom-mariee': 228,
#     'Nom-mariee': 249,
#     'Profession-mariee': 49,
#     'Ville-naissance-mariee': 71,
#     'Jour-naissance-mariee': 119,
#     'Mois-naissance-mariee': 136,
#     'Annee-naissance-mariee': 150,
#     'Age-mariee': 179,
#     'Numero-rue-residence-mariee': 213,
#     'Type-rue-residence-mariee': 247,
#     'Nom-rue-residence-mariee': 273,
#     'Prenom-pere-mariee': 343,
#     'Nom-pere-mariee': 364,
#     'Profession-pere-mariee': 378,
#     'Numero-rue-residence-pere-mariee': 216,
#     'Type-rue-residence-pere-mariee': 250,
#     'Nom-rue-residence-pere-mariee': 276,
#     'Prenom-mere-mariee': 400,
#     'Nom-mere-mariee': 412,
#     'Profession-mere-mariee': 440,
#     'Numero-rue-residence-mere-mariee': 220,
#     'Type-rue-residence-mere-mariee': 254,
#     'Nom-rue-residence-mere-mariee': 280,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43,
#     'Numero-rue-residence-temoin-1': 77,
#     'Type-rue-residence-temoin-1': 87,
#     'Nom-rue-residence-temoin-1': 97
# }
# Key : Ville-residence-temoin-1 Ref : Levallois Perret Occurences :
# [('Levallois Perret', 117)]
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 38,
#     'Annee-mariage': 59,
#     'Heure-mariage': 119,
#     'Minute-mariage': 154,
#     'Prenom-mari': 201,
#     'Nom-mari': 228,
#     'Profession-mari': 62,
#     'Ville-naissance-mari': 104,
#     'Departement-naissance-mari': 139,
#     'Jour-naissance-mari': 179,
#     'Mois-naissance-mari': 204,
#     'Annee-naissance-mari': 248,
#     'Age-mari': 318,
#     'Numero-rue-residence-mari': 348,
#     'Type-rue-residence-mari': 364,
#     'Nom-rue-residence-mari': 380,
#     'Prenom-pere-mari': 416,
#     'Nom-pere-mari': 446,
#     'Prenom-mere-mari': 476,
#     'Nom-mere-mari': 497,
#     'Profession-mere-mari': 524,
#     'Ville-residence-mere-mari': 556,
#     'Prenom-mariee': 240,
#     'Nom-mariee': 261,
#     'Profession-mariee': 49,
#     'Ville-naissance-mariee': 71,
#     'Jour-naissance-mariee': 125,
#     'Mois-naissance-mariee': 142,
#     'Annee-naissance-mariee': 156,
#     'Age-mariee': 185,
#     'Numero-rue-residence-mariee': 219,
#     'Type-rue-residence-mariee': 253,
#     'Nom-rue-residence-mariee': 279,
#     'Prenom-pere-mariee': 349,
#     'Nom-pere-mariee': 370,
#     'Profession-pere-mariee': 384,
#     'Numero-rue-residence-pere-mariee': 222,
#     'Type-rue-residence-pere-mariee': 256,
#     'Nom-rue-residence-pere-mariee': 282,
#     'Prenom-mere-mariee': 406,
#     'Nom-mere-mariee': 418,
#     'Profession-mere-mariee': 446,
#     'Numero-rue-residence-mere-mariee': 226,
#     'Type-rue-residence-mere-mariee': 260,
#     'Nom-rue-residence-mere-mariee': 286,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43,
#     'Numero-rue-residence-temoin-1': 77,
#     'Type-rue-residence-temoin-1': 87,
#     'Nom-rue-residence-temoin-1': 97,
#     'Ville-residence-temoin-1': 117
# }
# Key : Prenom-temoin-2 Ref : Jean Occurences :
# [('Jeanne', 18), ('Jean', 100), ('Jean', 146)]
# Occurence : Jean Position : 100 Key : Nom-rue-residence-temoin-1 Begin : 97 End : 114
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 7
#       4     for key, label in labels.items():
#       5         if label != "":
#       6             #print("\n\n")
# ----> 7             text[paragraph] = insert_emojis_around_label(key, paragraph, text[paragraph])
#       8             #print(text[paragraph])
#       9             #print("\n\n")
#      10 final = fix_pluriels(text)
#
# Cell In[142], line 148, in insert_emojis_around_label(label, paragraph, text, act)
#     145     positions[label] = occurences[0][1]
#     146     return occurences[0]
# --> 148 good_occ, pos = search_best_position(occurences)
#     149 print(positions)
#     150 def update_positions(pos, len_after, len_before, positions = positions):
#
# Cell In[142], line 38, in insert_emojis_around_label.<locals>.search_best_position(occurences, positions, label, oc)
#      36                 if occurence[1] >= begin and occurence[1] <= end:
#      37                     print("Occurence :", occurence[0], "Position :", occurence[1], "Key :", key, "Begin :", begin, "End :", end)
# ---> 38                     occurences.pop(occurence)
#      40 if 'mere-mariee' in label:
#      41     if label == 'Prenom-mere-mariee':
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
print(positions)
# Out:
# {
#     'Jour-mariage': 11,
#     'Mois-mariage': 38,
#     'Annee-mariage': 59,
#     'Heure-mariage': 129,
#     'Minute-mariage': 172,
#     'Prenom-mari': 237,
#     'Nom-mari': 300,
#     'Profession-mari': 62,
#     'Ville-naissance-mari': 108,
#     'Departement-naissance-mari': 149,
#     'Jour-naissance-mari': 197,
#     'Mois-naissance-mari': 222,
#     'Annee-naissance-mari': 284,
#     'Age-mari': 354,
#     'Numero-rue-residence-mari': 384,
#     'Type-rue-residence-mari': 404,
#     'Nom-rue-residence-mari': 424,
#     'Prenom-pere-mari': 464,
#     'Nom-pere-mari': 494,
#     'Prenom-mere-mari': 524,
#     'Nom-mere-mari': 545,
#     'Profession-mere-mari': 572,
#     'Ville-residence-mere-mari': 604,
#     'Prenom-mariee': 312,
#     'Nom-mariee': 333,
#     'Profession-mariee': 49,
#     'Ville-naissance-mariee': 71,
#     'Jour-naissance-mariee': 135,
#     'Mois-naissance-mariee': 152,
#     'Annee-naissance-mariee': 174,
#     'Age-mariee': 203,
#     'Numero-rue-residence-mariee': 237,
#     'Type-rue-residence-mariee': 289,
#     'Nom-rue-residence-mariee': 315,
#     'Prenom-pere-mariee': 385,
#     'Nom-pere-mariee': 414,
#     'Profession-pere-mariee': 428,
#     'Numero-rue-residence-pere-mariee': 246,
#     'Type-rue-residence-pere-mariee': 292,
#     'Nom-rue-residence-pere-mariee': 318,
#     'Prenom-mere-mariee': 454,
#     'Nom-mere-mariee': 466,
#     'Profession-mere-mariee': 494,
#     'Numero-rue-residence-mere-mariee': 256,
#     'Type-rue-residence-mere-mariee': 296,
#     'Nom-rue-residence-mere-mariee': 322,
#     'Prenom-temoin-1': 16,
#     'Nom-temoin-1': 27,
#     'Profession-temoin-1': 43,
#     'Numero-rue-residence-temoin-1': 77,
#     'Type-rue-residence-temoin-1': 87,
#     'Nom-rue-residence-temoin-1': 97,
#     'Ville-residence-temoin-1': 121,
#     'Prenom-temoin-2': 100,
#     'Nom-temoin-2': 155,
#     'Profession-temoin-2': 167,
#     'Numero-rue-residence-temoin-2': 237,
#     'Type-rue-residence-temoin-2': 246,
#     'Nom-rue-residence-temoin-2': 256,
#     'Prenom-adjoint-maire': 394,
#     'Nom-adjoint-maire': 404,
#     'Ville-mariage': 438
# }
