# %%
questions_dict = {
    "Jour-mariage": {"begin": "📖🌞", "end": "📕🌝"},
    "Mois-mariage": {"begin": "📖📅", "end": "📕📆"},
    "Annee-mariage": {"begin": "📖🗓", "end": "📕🎉"},
    "Heure-mariage": {"begin": "📖⏰", "end": "📕⌚"},
    "Minute-mariage": {"begin": "📖🕑", "end": "📕🕘"},
    "Prenom-adjoint-maire": {"begin": "📖💬", "end": "📕🗯"},
    "Nom-adjoint-maire": {"begin": "📖🗨", "end": "📕💭"},
    "Ville-mariage": {"begin": "📖🌇", "end": "📕🌉"},
    "Prenom-mari": {"begin": "👨💬", "end": "👦🗯"},
    "Nom-mari": {"begin": "👨🗨", "end": "👦💭"},
    "Profession-mari": {"begin": "👨🔧", "end": "👦🪛"},
    "Ville-naissance-mari": {"begin": "👨🏥🌇", "end": "👦👶🌉"},
    "Departement-naissance-mari": {"begin": "👨🏥🗺", "end": "👦👶📌"},
    "Pays-naissance-mari": {"begin": "👨🏥🏳", "end": "👦👶🌍"},
    "Jour-naissance-mari": {"begin": "👨🏥🌞", "end": "👦👶🌝"},
    "Mois-naissance-mari": {"begin": "👨🏥📅", "end": "👦👶📆"},
    "Annee-naissance-mari": {"begin": "👨🏥🗓", "end": "👦👶🎉"},
    "Age-mari": {"begin": "👨⌛", "end": "👦⏳"},
    "Ville-residence-mari": {"begin": "👨🏠🌇", "end": "👦🏡🌉"},
    "Departement-residence-mari": {"begin": "👨🏠🗺", "end": "👦🏡📌"},
    "Pays-residence-mari": {"begin": "👨👴🏠🏳", "end": "👦🎩🏡🌍"},
    "Numero-rue-residence-mari": {"begin": "👨🏠🔟", "end": "👦🏡🔢"},
    "Type-rue-residence-mari": {"begin": "👨🏠🛣", "end": "👦🏡🛤"},
    "Nom-rue-residence-mari": {"begin": "👨🏠🔠", "end": "👦🏡🔡"},
    "Prenom-pere-mari": {"begin": "👨👴💬", "end": "👦🎩🗯"},
    "Nom-pere-mari": {"begin": "👨👴🗨", "end": "👦🎩💭"},
    "Profession-pere-mari": {"begin": "👨👴🔧", "end": "👦🎩🪛"},
    "Ville-residence-pere-mari": {"begin": "👨👴🏠🌇", "end": "👦🎩🏡🌉"},
    "Departement-residence-pere-mari": {"begin": "👨👴🏠🗺", "end": "👦🎩🏡📌"},
    "Numero-residence-pere-mari": {"begin": "👨👴🏠🔟", "end": "👦🎩🏡🔢"},
    "Type-rue-residence-pere-mari": {"begin": "👨👴🏠🛣", "end": "👦🎩🏡🛤"},
    "Nom-rue-residence-pere-mari": {"begin": "👨👴🏠🔠", "end": "👦🎩🏡🔡"},
    "Prenom-mere-mari": {"begin": "👨👵💬", "end": "👦👒🗯"},
    "Nom-mere-mari": {"begin": "👨👵🗨", "end": "👦👒💭"},
    "Profession-mere-mari": {"begin": "👨👵🔧", "end": "👦👒🪛"},
    "Ville-residence-mere-mari": {"begin": "👨👵🏠🌇", "end": "👦👒🏡🌉"},
    "Departement-residence-mere-mari": {"begin": "👨👵🏠🗺", "end": "👦👒🏡📌"},
    "Pays-residence-mere-mari": {"begin": "👨👵🏠🏳", "end": "👦👒🏡🌍"},
    "Numero-rue-residence-mere-mari": {"begin": "👨👵🏠🔟", "end": "👦👒🏡🔢"},
    "Type-rue-residence-mere-mari": {"begin": "👨👵🏠🛣", "end": "👦👒🏡🛤"},
    "Nom-rue-residence-mere-mari": {"begin": "👨👵🏠🔠", "end": "👦👒🏡🔡"},
    "Prenom-ex-epouse": {"begin": "👨👹💬", "end": "👧😡🗯"},
    "Nom-ex-epouse": {"begin": "👨👹🗨", "end": "👦😡💭"},
    "Prenom-mariee": {"begin": "👰💬", "end": "👦🗯"},
    "Nom-mariee": {"begin": "👰🗨", "end": "👧💭"},
    "Profession-mariee": {"begin": "👰🔧", "end": "👧🪛"},
    "Ville-naissance-mariee": {"begin": "👰🏥🌇", "end": "👧👶🌉"},
    "Departement-naissance-mariee": {"begin": "👰🏥🗺", "end": "👧👶📌"},
    "Pays-naissance-mariee": {"begin": "👰🏥🏳", "end": "👧👶🌍"},
    "Jour-naissance-mariee": {"begin": "👰🏥🌞", "end": "👧👶🌝"},
    "Mois-naissance-mariee": {"begin": "👰🏥📅", "end": "👧👶📆"},
    "Annee-naissance-mariee": {"begin": "👰🏥🗓", "end": "👧👶🎉"},
    "Age-mariee": {"begin": "👰⌛", "end": "👧⏳"},
    "Ville-residence-mariee": {"begin": "👰🏠🌇", "end": "👧🏡🌉"},
    "Departement-residence-mariee": {"begin": "👰🏠🗺", "end": "👧🏡📌"},
    "Pays-residence-mariee": {"begin": "👰👴🏠🏳", "end": "👧🎩🏡🌍"},
    "Numero-rue-residence-mariee": {"begin": "👰🏠🔟", "end": "👧🏡🔢"},
    "Type-rue-residence-mariee": {"begin": "👰🏠🛣", "end": "👧🏡🛤"},
    "Nom-rue-residence-mariee": {"begin": "👰🏠🔠", "end": "👧🏡🔡"},
    "Prenom-pere-mariee": {"begin": "👰👴💬", "end": "👧🎩🗯"},
    "Nom-pere-mariee": {"begin": "👰👴🗨", "end": "👧🎩💭"},
    "Profession-pere-mariee": {"begin": "👰👴🔧", "end": "👧🎩🪛"},
    "Ville-residence-pere-mariee": {"begin": "👰👴🏠🌇", "end": "👧🎩🏡🌉"},
    "Departement-residence-pere-mariee": {"begin": "👰👴🏠🗺", "end": "👧🎩🏡📌"},
    "Numero-residence-pere-mariee": {"begin": "👰👴🏠🔟", "end": "👧🎩🏡🔢"},
    "Type-rue-residence-pere-mariee": {"begin": "👰👴🏠🛣", "end": "👧🎩🏡🛤"},
    "Nom-rue-residence-pere-mariee": {"begin": "👰👴🏠🔠", "end": "👧🎩🏡🔡"},
    "Prenom-mere-mariee": {"begin": "👰👵💬", "end": "👧👒🗯"},
    "Nom-mere-mariee": {"begin": "👰👵🗨", "end": "👧👒💭"},
    "Profession-mere-mariee": {"begin": "👰👵🔧", "end": "👧👒🪛"},
    "Ville-residence-mere-mariee": {"begin": "👰👵🏠🌇", "end": "👧👒🏡🌉"},
    "Departement-residence-mere-mariee": {"begin": "👰👵🏠🗺", "end": "👧👒🏡📌"},
    "Pays-residence-mere-mariee": {"begin": "👰👵🏠🏳", "end": "👧👒🏡🌍"},
    "Numero-rue-residence-mere-mariee": {"begin": "👰👵🏠🔟", "end": "👧👒🏡🔢"},
    "Type-rue-residence-mere-mariee": {"begin": "👰👵🏠🛣", "end": "👧👒🏡🛤"},
    "Nom-rue-residence-mere-mariee": {"begin": "👰👵🏠🔠", "end": "👧👒🏡🔡"},
    "Prenom-ex-epoux": {"begin": "👰👹💬", "end": "👧😡🗯"},
    "Nom-ex-epoux": {"begin": "👰👹🗨", "end": "👧😡💭"},
    "Prenom-temoin-1": {"begin": "🥸💬", "end": "🧐🗯"},
    "Nom-temoin-1": {"begin": "🥸🗨", "end": "🧐💭"},
    "Profession-temoin-1": {"begin": "🥸🔧", "end": "🧐🪛"},
    "Numero-rue-residence-temoin-1": {"begin": "🥸🏠🔟", "end": "🧐🏡🔢"},
    "Type-rue-residence-temoin-1": {"begin": "🥸🏠🛣", "end": "🧐🏡🛤"},
    "Nom-rue-residence-temoin-1": {"begin": "🥸🏠🔠", "end": "🧐🏡🔡"},
    "Ville-residence-temoin-1": {"begin": "🥸🏠🌇", "end": "🧐🏡🌉"},
    "Departement-residence-temoin-1": {"begin": "🥸🏠🗺", "end": "🧐🏡📌"},
    "Prenom-temoin-2": {"begin": "🥸💬", "end": "🧐🗯"},
    "Nom-temoin-2": {"begin": "🥸🗨", "end": "🧐💭"},
    "Profession-temoin-2": {"begin": "🥸🔧", "end": "🧐🪛"},
    "Numero-rue-residence-temoin-2": {"begin": "🥸🏠🔟", "end": "🧐🏡🔢"},
    "Type-rue-residence-temoin-2": {"begin": "🥸🏠🛣", "end": "🧐🏡🛤"},
    "Nom-rue-residence-temoin-2": {"begin": "🥸🏠🔠", "end": "🧐🏡🔡"},
    "Ville-residence-temoin-2": {"begin": "🥸🏠🌇", "end": "🧐🏡🌉"},
    "Departement-residence-temoin-2": {"begin": "🥸🏠🗺", "end": "🧐🏡📌"},

    'Profession-parents-mariee': {'begin': '👰👴👵🔧', 'end': '👧🎩👒🪛'},
    'Ville-residence-parents-mariee': {'begin': '👰👴👵🏠🌇', 'end': '👧🎩👒🏡🌉'},
    'Departement-residence-parents-mariee': {'begin': '👰👴👵🏠🗺', 'end': '👧🎩👒🏡📌'},
    'Pays-residence-mariee': {'begin': '👰👴👵🏠🏳', 'end': '👧🎩👒🏡🌍'},
    'Numero-residence-parents-mariee': {'begin': '👰👴👵🏠🔟', 'end': '👧🎩👒🏡🔢'},
    'Type-rue-residence-parents-mariee': {'begin': '👰👴👵🏠🛣', 'end': '👧🎩👒🏡🛤'},
    'Nom-rue-residence-parents-mariee': {'begin': '👰👴👵🏠🔠', 'end': '👧🎩👒🏡🔡'},
    'Profession-parents-mari': {'begin': '👨👴👵🔧', 'end': '👦🎩👒🪛'},
    'Ville-residence-parents-mari': {'begin': '👨👴👵🏠🌇', 'end': '👦🎩👒🏡🌉'},
    'Departement-residence-parents-mari': {'begin': '👨👴👵🏠🗺', 'end': '👦🎩👒🏡📌'},
}

questions_bool = {
    "Mère-mari-décédée": {"begin": "👨👵💬🪦", "end": "👦👒🗯⚰"},
    "Mère-mariee-décédée": {"begin": "👰👵💬🪦", "end": "👧👒🗯⚰"},
    "Père-mari-décédée": {"begin": "👨👴💬🪦", "end": "👦🎩🗯⚰"},
    "Père-mariee-décédée": {"begin": "👰👴💬🪦", "end": "👧🎩🗯⚰"},
    "Mari-veuf": {"begin": "👨💬😢", "end": "👦🗯😭"},
    "Mariée-veuve": {"begin": "👰💬😢", "end": "👧🗯😭"},
    "Mariée-a-un-ex-époux": {"begin": "👰👹", "end": "👧😡"},
    "Mari-a-une-ex-épouse": {"begin": "👨👹", "end": "👦😡"},
}

# %%
positions = {}

labels_act = {
    "archives_AD075EC_01M1930_0023-left.png-0": {
        "p1": {
            "Jour-mariage": "vingt-neuf",
            "Mois-mariage": "mars",
            "Annee-mariage": "mil neuf cent trente",
            "Heure-mariage": "onze heures",
            "Minute-mariage": "vingt minutes",
        },
        "p2": {
            "Prenom-mari": "Albert",
            "Nom-mari": "VOLOVITSCH",
            "Profession-mari": "commissionnaire en marchandises",
            "Ville-naissance-mari": "Saint Quentin ",
            "Departement-naissance-mari": "Aisne",
            "Pays-naissance-mari": "",
            "Jour-naissance-mari": "dix",
            "Mois-naissance-mari": "octobre",
            "Annee-naissance-mari": "mil huit cent quatre-vingt-six",
            "Age-mari": "quarante-trois ans",
            "Ville-residence-mari": "Paris",
            "Departement-residence-mari": "",
            "Pays-residence-mari": "",
            "Numero-rue-residence-mari": "40",
            "Type-rue-residence-mari": "rue",
            "Nom-rue-residence-mari": "des Martyrs",
            "Prenom-pere-mari": "Jules",
            "Nom-pere-mari": "VOLOVITSCH",
            #"Pere-mari-decede": "true",
            "Profession-pere-mari": "",
            "Ville-residence-pere-mari": "",
            "Departement-residence-pere-mari": "",
            "Pays-residence-pere-mari": "",
            "Numero-rue-residence-pere-mari": "",
            "Type-rue-residence-pere-mari": "",
            "Nom-rue-residence-pere-mari": "",
            "Prenom-mere-mari": "",
            "Nom-mere-mari": "Fanny LEWINSON",
            #"Mere-mari-decedee": "true",
            "Profession-mere-mari": "",
            "Ville-residence-mere-mari": "",
            "Departement-residence-mere-mari": "",
            "Pays-residence-mere-mari": "",
            "Numero-rue-residence-mere-mari": "",
            "Type-rue-residence-mere-mari": "",
            "Nom-rue-residence-mere-mari": "",
            #"Mari-a-ex-epouse": "false",
            #"Mari-veuf": "false",
            "Prenom-ex-epouse": "",
            "Nom-ex-epouse": ""
        },
        "p3": {
            "Prenom-mariee": "Marguerite C\u00e9lina",
            "Nom-mariee": "MITTE",
            "Profession-mariee": "couturi\u00e8re",
            "Ville-naissance-mariee": "Choisy-le-Roi",
            "Departement-naissance-mariee": "Seine",
            "Pays-naissance-mariee": "",
            "Jour-naissance-mariee": "vingt-dis",
            "Mois-naissance-mariee": "novembre",
            "Annee-naissance-mariee": "mil huit cent quatre-vingt-treize",
            "Age-mariee": "trentesix ans",
            "Ville-residence-mariee": "Paris",
            "Departement-residence-mariee": "",
            "Pays-residence-mariee": "",
            "Numero-rue-residence-mariee": "168",
            "Type-rue-residence-mariee": "rue",
            "Nom-rue-residence-mariee": "Saint Hono\u00e9",
            "Prenom-pere-mariee": "Emile Henri Paul",
            "Nom-pere-mariee": "MITTE",
            # "Pere-mariee-decede": "false",
            "Profession-pere-mariee": "chauffeur",
            "Ville-residence-pere-mariee": "",
            "Departement-residence-pere-mariee": "",
            "Numero-rue-residence-pere-mariee": "",
            "Type-rue-residence-pere-mariee": "",
            "Nom-rue-residence-pere-mariee": "",
            "Prenom-mere-mariee": "Flore",
            "Nom-mere-mariee": "LEBEGUE",
            # "Mere-mariee-decedee": "false",
            "Profession-mere-mariee": "sans profession",
            "Ville-residence-mere-mariee": "Choisy-le-Roi",
            "Departement-residence-mere-mariee": "",
            "Pays-residence-mere-mariee": "",
            "Numero-rue-residence-mere-mariee": "15",
            "Type-rue-residence-mere-mariee": "rue",
            "Nom-rue-residence-mere-mariee": "Passereau",
            # "Mariee-a-ex-epoux": "false",
            # "Mariee-veuve": "false",
            "Prenom-ex-epoux": "",
            "Nom-ex-epoux": "",
            
        },
        "p4": {
            "Prenom-mari": "Albert",
            "Nom-mari": "VOLOVITSCH",
            "Prenom-mariee": "Marguerite C\u00e9lina",
            "Nom-mariee": "MITTE",
        },
        "p5": {
            "Prenom-temoin-1": "H\u00e9l\u00e8ne",
            "Nom-temoin-1": "SCHEIMANN",
            "Profession-temoin-1": "sans profession",
            "Numero-rue-residence-temoin-1": "7",
            "Type-rue-residence-temoin-1": "rue",
            "Nom-rue-residence-temoin-1": "Montyon",
            "Ville-residence-temoin-1": "",
            "Departement-residence-temoin-1": "",
            "Prenom-temoin-2": "Auguste",
            "Nom-temoin-2": "SEJOURNE",
            "Profession-temoin-2": "peintre en batiment",
            "Numero-rue-residence-temoin-2": "21 ter",
            "Type-rue-residence-temoin-2": "rue",
            "Nom-rue-residence-temoin-2": "Emile Zola",
            "Ville-residence-temoin-2": "Choisy-le-Roi",
            "Departement-residence-temoin-2": "Seine",
            "Prenom-adjoint-maire": "Jean Joseph",
            "Nom-adjoint-maire": "POULALION",
            "Ville-mariage": "Premier arrondissement de Paris",
        }
    }
}

text = {
    "p1": "Le vingt-neuf mars mil neuf cent trente, onze heures vingt minutes ****\ndevant Nous ont comparu publiquement en la maison commune:",
    "p2": "Albert VOLOVITSCH, commissionnaire\nen marchandises, n\u00e9 \u00e0 Saint Quentin (Aisne) le dix octobre mil huit cent quatre-vingt-six,\nquarante-trois ans, domicili\u00e9 \u00e0 Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *\nFanny LEWINSON, son \u00e9pouse, d\u00e9c\u00e9d\u00e9s; d'une part ,/-",
    "p3": "ET Marguerite C\u00e9lina MITTE, couturi\u00e8re,\nn\u00e9e \u00e0 Choisy-le-Roi (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-\nsix ans, domicili\u00e9e \u00e0 Paris, 168, rue Saint Hono\u00e9; fille de Emile Henri Paul MITTE, chauffeur,\net de Flore LEBEGUE, son \u00e9pouse, sans profession, domicili\u00e9es \u00e0 Choisy-le-Roi, 15, rue Passereau\nd'autre part ;- ",
    "p4": "aucune opposition n'existant. Les futurs \u00e9poux d\u00e9clarent qu'il n'a pas \u00e9t\u00e9\nfait de contrat de mariage .- Albert VOLOVITSCH et Marguerite C\u00e9lina MITTE ont d\u00e9clar\u00e9 l'un\napr\u00e8s l'autre vouloir se prendre pour \u00e9poux et Nous avons prononc\u00e9 au nom de la Loi qu'ils\nsont unis par le mariage.",
    "p5": "En pr\u00e9sence de: H\u00e9l\u00e8ne SCHEIMANN, sans profession, 7, rue\nMontyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile\nZola \u00e0 Choisy-le-Roi (Seine) t\u00e9moins majeurs, qui, lecture faite, ont sign\u00e9 avec les \u00e9poux\net Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la\nL\u00e9gion d'Honneur ./."
}

# %%
import Levenshtein
import re


def check_for_occurence(occ, text = text):
    #check for occurences of occ in text
    #return a list of tuples (occurence, position) from the first to the last occurence in the text.
    #allow a levenshtein distance of 1/4 of the length of occ and 0 if occ is shorter than 4 characters

    if len(occ) < 4:
        lev = 0
    else:
        lev = len(occ)//3

    print("check_for_occurence -> occ : ", occ, "lev : ", lev)
    occurences = []
    for i in range(len(text) - len(occ)):
        if Levenshtein.distance(occ, text[i:i+len(occ)]) <= lev:
            #check if there is already an occurence in the list in the len(occ) characters before (overlapping occurences)
            #if there is, replace it with the new one only if it is a better match
            if len(occurences) > 0 and occurences[-1][1] > i - len(occ):
                #print(occurences[-1][1], i - len(occ))
                #print("Old : ",text[occurences[-1][1]:occurences[-1][1]+len(occ)])
                #print("New :",text[i:i+len(occ)])
                if Levenshtein.distance(occ, text[occurences[-1][1]:occurences[-1][1]+len(occ)]) > Levenshtein.distance(occ, text[i:i+len(occ)]):
                    occurences[-1] = (text[i:i+len(occ)], i)
            else:
                occurences.append((text[i:i+len(occ)], i))
    return occurences

# %%
check_for_occurence("mil huit cent quatre-vingt-treize", text["p3"])
# Out:
# check_for_occurence -> occ :  mil huit cent quatre-vingt-treize lev :  11
# [('mil huit cent quatre-vingt-treize', 90)]

# %%
def insert_emojis_around_label(label, paragraph, text = text):
    #insert emojis around occ in text
    #return the text with emojis around occ
    #if occ is not found, return None

    emojis = questions_dict[label]
    occ = labels_act["archives_AD075EC_01M1930_0023-left.png-0"][paragraph][label]
    # print("Occurence :", occ)
    occurences = check_for_occurence(occ, text)
    print("Key :", label, "Ref :", occ, "Occurences :", occurences)
    if len(occurences) == 0:
        return
    else:
        #the position of the occurence in the text is occurences[0][1]

        def search_best_position(occurences, positions = positions, label = label):
            if 'mere-mariee' in label :
                if label == 'Prenom-mere-mariee':
                    positions['Prenom-mere-mariee'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-mere-mariee':
                #     positions['Nom-mere-mariee'] = occurences[0][1]
                #     return occurences[0]
                
                p = positions['Prenom-mere-mariee'] if ('Prenom-mere-mariee' in positions.keys()) else 0
                
                #choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        return occ
                    
                #si aucune occurence après p, choisir la dernière occurence
                return occurences[-1]
            
            if 'pere-mariee' in label :
                if label == 'Prenom-pere-mariee':
                    positions['Prenom-pere-mariee'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-pere-mariee':
                #     positions['Nom-pere-mariee'] = occurences[0][1]
                #     return occurences[0]
                
                p = positions['Prenom-pere-mariee'] if ('Prenom-pere-mariee' in positions.keys()) else 0
                
                #choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        return occ
                    
                #si aucune occurence après p, choisir la dernière occurence
                return occurences[-1]
            
            if 'mere-mari' in label :
                if label == 'Prenom-mere-mari':
                    positions['Prenom-mere-mari'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-mere-mari':
                #     positions['Nom-mere-mari'] = occurences[0][1]
                #     return occurences[0]
                
                p = positions['Prenom-mere-mari'] if ('Prenom-mere-mari' in positions.keys()) else 0
                
                #choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        return occ
                    
                #si aucune occurence après p, choisir la dernière occurence
                return occurences[-1]
            
            if 'pere-mari' in label :
                if label == 'Prenom-pere-mari':
                    positions['Prenom-pere-mari'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-pere-mari':
                #     positions['Nom-pere-mari'] = occurences[0][1]
                #     return occurences[0]
                
                p = positions['Prenom-pere-mari'] if ('Prenom-pere-mari' in positions.keys()) else 0
                
                #choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        return occ
                    
                #si aucune occurence après p, choisir la dernière occurence
                return occurences[-1]

            if 'temoin-2' in label :
                if label == 'Prenom-temoin-2':
                    positions['Prenom-temoin-2'] = occurences[0][1]
                    return occurences[0]
                # elif label == 'Nom-temoin-2':
                #     positions['Nom-temoin-2'] = occurences[0][1]
                #     return occurences[0]
                
                p = positions['Prenom-temoin-2'] if ('Prenom-temoin-2' in positions.keys()) else 0
                
                #choisir la première occurence après p
                for occ in occurences:
                    if occ[1] > p:
                        return occ
                    
                #si aucune occurence après p, choisir la dernière occurence
                return occurences[-1]
                
            return occurences[0]
        
            
                
            
        good_occ, pos = search_best_position(occurences)

        #I want to insert emojis around the occurence, I want this to be done only for good_occ
        text = text[:pos] + emojis['begin'] + good_occ + emojis['end'] + text[pos+len(good_occ):]
  
        print("Text :", text)
        return text

# %%
for paragraph, labels  in labels_act["archives_AD075EC_01M1930_0023-left.png-0"].items():
    
    for key, label in labels.items():
        if label != "":
            print("\n\n")
            text[paragraph] = insert_emojis_around_label(key, paragraph, text[paragraph])

print(text)
# Out:
# check_for_occurence -> occ :  vingt-neuf lev :  3
# Key : Jour-mariage Ref : vingt-neuf Occurences : [('vingt-neuf', 3)]
# Text : Le 📖🌞vingt-neuf📕🌝 mars mil neuf cent trente, onze heures vingt minutes ****
# devant Nous ont comparu publiquement en la maison commune:
#
#
#
# check_for_occurence -> occ :  mars lev :  1
# Key : Mois-mariage Ref : mars Occurences : [('mars', 18), ('mais', 119)]
# Text : Le 📖🌞vingt-neuf📕🌝 📖📅mars📕📆 mil neuf cent trente, onze heures vingt minutes ****
# devant Nous ont comparu publiquement en la maison commune:
#
#
#
# check_for_occurence -> occ :  mil neuf cent trente lev :  6
# Key : Annee-mariage Ref : mil neuf cent trente Occurences : [('mil neuf cent trente', 27)]
# Text : Le 📖🌞vingt-neuf📕🌝 📖📅mars📕📆 📖🗓mil neuf cent trente📕🎉, onze heures vingt minutes ****
# devant Nous ont comparu publiquement en la maison commune:
#
#
#
# check_for_occurence -> occ :  onze heures lev :  3
# Key : Heure-mariage Ref : onze heures Occurences : [('onze heures', 53)]
# Text : Le 📖🌞vingt-neuf📕🌝 📖📅mars📕📆 📖🗓mil neuf cent trente📕🎉, 📖⏰onze heures📕⌚ vingt minutes ****
# devant Nous ont comparu publiquement en la maison commune:
#
#
#
# check_for_occurence -> occ :  vingt minutes lev :  4
# Key : Minute-mariage Ref : vingt minutes Occurences : [('vingt minutes', 69)]
# Text : Le 📖🌞vingt-neuf📕🌝 📖📅mars📕📆 📖🗓mil neuf cent trente📕🎉, 📖⏰onze heures📕⌚ 📖🕑vingt minutes📕🕘 ****
# devant Nous ont comparu publiquement en la maison commune:
#
#
#
# check_for_occurence -> occ :  Albert lev :  2
# Key : Prenom-mari Ref : Albert Occurences : [('Albert', 0)]
# Text : 👨💬Albert👦🗯 VOLOVITSCH, commissionnaire
# en marchandises, né à Saint Quentin (Aisne) le dix octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  VOLOVITSCH lev :  3
# Key : Nom-mari Ref : VOLOVITSCH Occurences : [('VOLOVITSCH', 11), ('VOLOVITSCH', 204)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, commissionnaire
# en marchandises, né à Saint Quentin (Aisne) le dix octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  commissionnaire en marchandises lev :  10
# Key : Profession-mari Ref : commissionnaire en marchandises Occurences : [('commissionnaire\nen marchandises', 27)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à Saint Quentin (Aisne) le dix octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Saint Quentin  lev :  4
# Key : Ville-naissance-mari Ref : Saint Quentin  Occurences : [('Saint Quentin ', 69)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(Aisne) le dix octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Aisne lev :  1
# Key : Departement-naissance-mari Ref : Aisne Occurences : [('Aisne', 90)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le dix octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  dix lev :  0
# Key : Jour-naissance-mari Ref : dix Occurences : [('dix', 106)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 octobre mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  octobre lev :  2
# Key : Mois-naissance-mari Ref : octobre Occurences : [('octobre', 116)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 mil huit cent quatre-vingt-six,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  mil huit cent quatre-vingt-six lev :  10
# Key : Annee-naissance-mari Ref : mil huit cent quatre-vingt-six Occurences : [('mil huit cent quatre-vingt-six', 130)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# quarante-trois ans, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  quarante-trois ans lev :  6
# Key : Age-mari Ref : quarante-trois ans Occurences : [('quarante-trois ans', 168)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à Paris, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Paris lev :  1
# Key : Ville-residence-mari Ref : Paris Occurences : [('Paris', 204)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 40, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  40 lev :  0
# Key : Numero-rue-residence-mari Ref : 40 Occurences : [('40', 217)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, rue des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  rue lev :  0
# Key : Type-rue-residence-mari Ref : rue Occurences : [('rue', 227)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 des Martyrs; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  des Martyrs lev :  3
# Key : Nom-rue-residence-mari Ref : des Martyrs Occurences : [('des Martyrs', 237)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 👨🏠🔠des Martyrs👦🏡🔡; fils de Jules VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Jules lev :  1
# Key : Prenom-pere-mari Ref : Jules Occurences : [('Jules', 264)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 👨🏠🔠des Martyrs👦🏡🔡; fils de 👨👴💬Jules👦🎩🗯 VOLOVITSCH et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  VOLOVITSCH lev :  3
# Key : Nom-pere-mari Ref : VOLOVITSCH Occurences : [('VOLOVITSCH', 13), ('VOLOVITSCH', 276)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 👨🏠🔠des Martyrs👦🏡🔡; fils de 👨👴💬Jules👦🎩🗯 👨👴🗨VOLOVITSCH👦🎩💭 et de * *
# Fanny LEWINSON, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Fanny LEWINSON lev :  4
# Key : Nom-mere-mari Ref : Fanny LEWINSON Occurences : [('Fanny LEWINSON', 303)]
# Text : 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire
# en marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,
# 👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 👨🏠🔠des Martyrs👦🏡🔡; fils de 👨👴💬Jules👦🎩🗯 👨👴🗨VOLOVITSCH👦🎩💭 et de * *
# 👨👵🗨Fanny LEWINSON👦👒💭, son épouse, décédés; d'une part ,/-
#
#
#
# check_for_occurence -> occ :  Marguerite Célina lev :  5
# Key : Prenom-mariee Ref : Marguerite Célina Occurences : [('Marguerite Célina', 3)]
# Text : ET 👰💬Marguerite Célina👦🗯 MITTE, couturière,
# née à Choisy-le-Roi (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  MITTE lev :  1
# Key : Nom-mariee Ref : MITTE Occurences : [('MITTE', 25), ('MITTE', 214)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, couturière,
# née à Choisy-le-Roi (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  couturière lev :  3
# Key : Profession-mariee Ref : couturière Occurences : [('couturière', 36)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à Choisy-le-Roi (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Choisy-le-Roi lev :  4
# Key : Ville-naissance-mariee Ref : Choisy-le-Roi Occurences : [('Choisy-le-Roi', 58), ('Choisy-le-Roi', 304)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (Seine) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Seine lev :  1
# Key : Departement-naissance-mariee Ref : Seine Occurences : [('Seine', 79)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le vingt-dis novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  vingt-dis lev :  3
# Key : Jour-naissance-mariee Ref : vingt-dis Occurences : [('vingt-dis', 95), ('vingt-tre', 135)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 novembre mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  novembre lev :  2
# Key : Mois-naissance-mariee Ref : novembre Occurences : [('novembre', 111)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 mil huit cent quatre-vingt-treize, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  mil huit cent quatre-vingt-treize lev :  11
# Key : Annee-naissance-mariee Ref : mil huit cent quatre-vingt-treize Occurences : [('mil huit cent quatre-vingt-treize', 126)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, trente-
# six ans, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  trentesix ans lev :  4
# Key : Age-mariee Ref : trentesix ans Occurences : [('trente-\nsix a', 167)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à Paris, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Paris lev :  1
# Key : Ville-residence-mariee Ref : Paris Occurences : [('Paris', 201)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 168, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  168 lev :  0
# Key : Numero-rue-residence-mariee Ref : 168 Occurences : [('168', 214)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, rue Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  rue lev :  0
# Key : Type-rue-residence-mariee Ref : rue Occurences : [('rue', 225), ('rue', 369)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 Saint Honoé; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Saint Honoé lev :  3
# Key : Nom-rue-residence-mariee Ref : Saint Honoé Occurences : [('Saint Honoé', 235)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de Emile Henri Paul MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Emile Henri Paul lev :  5
# Key : Prenom-pere-mariee Ref : Emile Henri Paul Occurences : [('Emile Henri Paul', 263)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 MITTE, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  MITTE lev :  1
# Key : Nom-pere-mariee Ref : MITTE Occurences : [('MITTE', 27), ('MITTE', 286)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, chauffeur,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  chauffeur lev :  3
# Key : Profession-pere-mariee Ref : chauffeur Occurences : [('chauffeur', 299)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de Flore LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Flore lev :  1
# Key : Prenom-mere-mariee Ref : Flore Occurences : [('Flore', 322)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 LEBEGUE, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  LEBEGUE lev :  2
# Key : Nom-mere-mariee Ref : LEBEGUE Occurences : [('LEBEGUE', 334)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, sans profession, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  sans profession lev :  5
# Key : Profession-mere-mariee Ref : sans profession Occurences : [('sans profession', 361)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à Choisy-le-Roi, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Choisy-le-Roi lev :  4
# Key : Ville-residence-mere-mariee Ref : Choisy-le-Roi Occurences : [('Choisy-le-Roi', 61), ('Choisy-le-Roi', 398)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à 👰👵🏠🌇Choisy-le-Roi👧👒🏡🌉, 15, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  15 lev :  0
# Key : Numero-rue-residence-mere-mariee Ref : 15 Occurences : [('15', 421)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à 👰👵🏠🌇Choisy-le-Roi👧👒🏡🌉, 👰👵🏠🔟15👧👒🏡🔢, rue Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  rue lev :  0
# Key : Type-rue-residence-mere-mariee Ref : rue Occurences : [('rue', 228), ('rue', 433)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à 👰👵🏠🌇Choisy-le-Roi👧👒🏡🌉, 👰👵🏠🔟15👧👒🏡🔢, 👰👵🏠🛣rue👧👒🏡🛤 Passereau
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Passereau lev :  3
# Key : Nom-rue-residence-mere-mariee Ref : Passereau Occurences : [('Passereau', 445)]
# Text : ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,
# née à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-
# six a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,
# et de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à 👰👵🏠🌇Choisy-le-Roi👧👒🏡🌉, 👰👵🏠🔟15👧👒🏡🔢, 👰👵🏠🛣rue👧👒🏡🛤 👰👵🏠🔠Passereau👧👒🏡🔡
# d'autre part ;-
#
#
#
# check_for_occurence -> occ :  Albert lev :  2
# Key : Prenom-mari Ref : Albert Occurences : [('Albert', 105)]
# Text : aucune opposition n'existant. Les futurs époux déclarent qu'il n'a pas été
# fait de contrat de mariage .- 👨💬Albert👦🗯 VOLOVITSCH et Marguerite Célina MITTE ont déclaré l'un
# après l'autre vouloir se prendre pour époux et Nous avons prononcé au nom de la Loi qu'ils
# sont unis par le mariage.
#
#
#
# check_for_occurence -> occ :  VOLOVITSCH lev :  3
# Key : Nom-mari Ref : VOLOVITSCH Occurences : [('VOLOVITSCH', 116)]
# Text : aucune opposition n'existant. Les futurs époux déclarent qu'il n'a pas été
# fait de contrat de mariage .- 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭 et Marguerite Célina MITTE ont déclaré l'un
# après l'autre vouloir se prendre pour époux et Nous avons prononcé au nom de la Loi qu'ils
# sont unis par le mariage.
#
#
#
# check_for_occurence -> occ :  Marguerite Célina lev :  5
# Key : Prenom-mariee Ref : Marguerite Célina Occurences : [('Marguerite Célina', 134)]
# Text : aucune opposition n'existant. Les futurs époux déclarent qu'il n'a pas été
# fait de contrat de mariage .- 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭 et 👰💬Marguerite Célina👦🗯 MITTE ont déclaré l'un
# après l'autre vouloir se prendre pour époux et Nous avons prononcé au nom de la Loi qu'ils
# sont unis par le mariage.
#
#
#
# check_for_occurence -> occ :  MITTE lev :  1
# Key : Nom-mariee Ref : MITTE Occurences : [('MITTE', 156)]
# Text : aucune opposition n'existant. Les futurs époux déclarent qu'il n'a pas été
# fait de contrat de mariage .- 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭 et 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭 ont déclaré l'un
# après l'autre vouloir se prendre pour époux et Nous avons prononcé au nom de la Loi qu'ils
# sont unis par le mariage.
#
#
#
# check_for_occurence -> occ :  Hélène lev :  2
# Key : Prenom-temoin-1 Ref : Hélène Occurences : [('Hélène', 16)]
# Text : En présence de: 🥸💬Hélène🧐🗯 SCHEIMANN, sans profession, 7, rue
# Montyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  SCHEIMANN lev :  3
# Key : Nom-temoin-1 Ref : SCHEIMANN Occurences : [('SCHEIMANN', 27)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, sans profession, 7, rue
# Montyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  sans profession lev :  5
# Key : Profession-temoin-1 Ref : sans profession Occurences : [('sans profession', 42)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 7, rue
# Montyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  7 lev :  0
# Key : Numero-rue-residence-temoin-1 Ref : 7 Occurences : [('7', 63)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, rue
# Montyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  rue lev :  0
# Key : Type-rue-residence-temoin-1 Ref : rue Occurences : [('rue', 72), ('rue', 153)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# Montyon et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Montyon lev :  2
# Key : Nom-rue-residence-temoin-1 Ref : Montyon Occurences : [('Montyon', 82)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de Auguste SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Auguste lev :  2
# Key : Prenom-temoin-2 Ref : Auguste Occurences : [('Auguste', 102)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 SEJOURNE peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  SEJOURNE lev :  2
# Key : Nom-temoin-2 Ref : SEJOURNE Occurences : [('SEJOURNE', 114)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 peintre en batiment, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  peintre en batiment lev :  6
# Key : Profession-temoin-2 Ref : peintre en batiment Occurences : [('peintre en batiment', 127)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 21 ter, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  21 ter lev :  2
# Key : Numero-rue-residence-temoin-2 Ref : 21 ter Occurences : [('21 ter', 169)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, rue Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  rue lev :  0
# Key : Type-rue-residence-temoin-2 Ref : rue Occurences : [('rue', 75), ('rue', 183)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 Emile
# Zola à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Emile Zola lev :  3
# Key : Nom-rue-residence-temoin-2 Ref : Emile Zola Occurences : [('Emile\nZola', 193)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à Choisy-le-Roi (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Choisy-le-Roi lev :  4
# Key : Ville-residence-temoin-2 Ref : Choisy-le-Roi Occurences : [('Choisy-le-Roi', 212)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (Seine) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Seine lev :  1
# Key : Departement-residence-temoin-2 Ref : Seine Occurences : [('Seine', 233)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (🥸🏠🗺Seine🧐🏡📌) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, Jean Joseph POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Jean Joseph lev :  3
# Key : Prenom-adjoint-maire Ref : Jean Joseph Occurences : [('Jean Joseph', 317)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (🥸🏠🗺Seine🧐🏡📌) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, 📖💬Jean Joseph📕🗯 POULALION, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  POULALION lev :  3
# Key : Nom-adjoint-maire Ref : POULALION Occurences : [('POULALION', 333)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (🥸🏠🗺Seine🧐🏡📌) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, 📖💬Jean Joseph📕🗯 📖🗨POULALION📕💭, Maire du Premier arrondissement de Paris, ChevaLier de la
# Légion d'Honneur ./.
#
#
#
# check_for_occurence -> occ :  Premier arrondissement de Paris lev :  10
# Key : Ville-mariage Ref : Premier arrondissement de Paris Occurences : [('Premier arrondissement de Paris', 357)]
# Text : En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤
# 🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile
# Zola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (🥸🏠🗺Seine🧐🏡📌) témoins majeurs, qui, lecture faite, ont signé avec les époux
# et Nous, 📖💬Jean Joseph📕🗯 📖🗨POULALION📕💭, Maire du 📖🌇Premier arrondissement de Paris📕🌉, ChevaLier de la
# Légion d'Honneur ./.
# {'p1': 'Le 📖🌞vingt-neuf📕🌝 📖📅mars📕📆 📖🗓mil neuf cent trente📕🎉, 📖⏰onze heures📕⌚ 📖🕑vingt minutes📕🕘 ****\ndevant Nous ont comparu publiquement en la maison commune:', 'p2': "👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭, 👨🔧commissionnaire\nen marchandises👦🪛, né à 👨🏥🌇Saint Quentin 👦👶🌉(👨🏥🗺Aisne👦👶📌) le 👨🏥🌞dix👦👶🌝 👨🏥📅octobre👦👶📆 👨🏥🗓mil huit cent quatre-vingt-six👦👶🎉,\n👨⌛quarante-trois ans👦⏳, domicilié à 👨🏠🌇Paris👦🏡🌉, 👨🏠🔟40👦🏡🔢, 👨🏠🛣rue👦🏡🛤 👨🏠🔠des Martyrs👦🏡🔡; fils de 👨👴💬Jules👦🎩🗯 👨👴🗨VOLOVITSCH👦🎩💭 et de * *\n👨👵🗨Fanny LEWINSON👦👒💭, son épouse, décédés; d'une part ,/-", 'p3': "ET 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭, 👰🔧couturière👧🪛,\nnée à 👰🏥🌇Choisy-le-Roi👧👶🌉 (👰🏥🗺Seine👧👶📌) le 👰🏥🌞vingt-dis👧👶🌝 👰🏥📅novembre👧👶📆 👰🏥🗓mil huit cent quatre-vingt-treize👧👶🎉, 👰⌛trente-\nsix a👧⏳ns, domiciliée à 👰🏠🌇Paris👧🏡🌉, 👰🏠🔟168👧🏡🔢, 👰🏠🛣rue👧🏡🛤 👰🏠🔠Saint Honoé👧🏡🔡; fille de 👰👴💬Emile Henri Paul👧🎩🗯 👰👴🗨MITTE👧🎩💭, 👰👴🔧chauffeur👧🎩🪛,\net de 👰👵💬Flore👧👒🗯 👰👵🗨LEBEGUE👧👒💭, son épouse, 👰👵🔧sans profession👧👒🪛, domiciliées à 👰👵🏠🌇Choisy-le-Roi👧👒🏡🌉, 👰👵🏠🔟15👧👒🏡🔢, 👰👵🏠🛣rue👧👒🏡🛤 👰👵🏠🔠Passereau👧👒🏡🔡\nd'autre part ;- ", 'p4': "aucune opposition n'existant. Les futurs époux déclarent qu'il n'a pas été\nfait de contrat de mariage .- 👨💬Albert👦🗯 👨🗨VOLOVITSCH👦💭 et 👰💬Marguerite Célina👦🗯 👰🗨MITTE👧💭 ont déclaré l'un\naprès l'autre vouloir se prendre pour époux et Nous avons prononcé au nom de la Loi qu'ils\nsont unis par le mariage.", 'p5': "En présence de: 🥸💬Hélène🧐🗯 🥸🗨SCHEIMANN🧐💭, 🥸🔧sans profession🧐🪛, 🥸🏠🔟7🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤\n🥸🏠🔠Montyon🧐🏡🔡 et de 🥸💬Auguste🧐🗯 🥸🗨SEJOURNE🧐💭 🥸🔧peintre en batiment🧐🪛, croix de guerre, 🥸🏠🔟21 ter🧐🏡🔢, 🥸🏠🛣rue🧐🏡🛤 🥸🏠🔠Emile\nZola🧐🏡🔡 à 🥸🏠🌇Choisy-le-Roi🧐🏡🌉 (🥸🏠🗺Seine🧐🏡📌) témoins majeurs, qui, lecture faite, ont signé avec les époux\net Nous, 📖💬Jean Joseph📕🗯 📖🗨POULALION📕💭, Maire du 📖🌇Premier arrondissement de Paris📕🌉, ChevaLier de la\nLégion d'Honneur ./."}
